# %%
# !pip install rdkit-pypi
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.4/29.4 MB 34.1 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
from rdkit import Chem
from rdkit.Chem import Draw
import matplotlib.pyplot as plt

# %%
def Filter(DataFrame):
  NewDataFrame = pd.DataFrame()
  NewDataFrame = DataFrame[(DataFrame['logP']>=1) & (DataFrame['logP']<=5)
                         & (DataFrame['Solubility_AqSolDB']>=-6) & (DataFrame['Solubility_AqSolDB']<=-4)
                         & (DataFrame['BBB_Martins']>0.5)
                         & (DataFrame['Lipinski']==4)
                         & (DataFrame['ClinTox']<0.5)
                         & (DataFrame['PAINS'] == '[]')
                         & (DataFrame['sa_score']<=2)]
  return NewDataFrame

# %% [markdown]
# # **PubChem**

# %% [markdown]
# ## *(4-hydroxynaphthalen-1-yl)sulfonamide*

# %%
url = 'https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/ADMET_analysis_p3/PubChem_sulfonamide_ADMET_p3.csv'
df_PubChem_sulfonamide_ADMET_p3 = pd.read_csv(url)

# %%
df_PubChem_sulfonamide_ADMET_temp = Filter(df_PubChem_sulfonamide_ADMET_p3)
df_PubChem_sulfonamide_ADMET_filtered = pd.DataFrame()
df_PubChem_sulfonamide_ADMET_filtered['smiles'] = df_PubChem_sulfonamide_ADMET_temp['smiles']

# %%
df_PubChem_sulfonamide_ADMET_filtered.to_csv('PubChem_sulfonamide_ADMET_filtered.csv', index=False)

# %% [markdown]
# ## *Indolinone*

# %%
url = 'https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/ADMET_analysis_p3/PubChem_indolinone_ADMET_p3.csv'
df_PubChem_indolinone_ADMET_p3 = pd.read_csv(url)

# %%
df_PubChem_indolinone_ADMET_temp = Filter(df_PubChem_indolinone_ADMET_p3)
df_PubChem_indolinone_ADMET_filtered = pd.DataFrame()
df_PubChem_indolinone_ADMET_filtered['smiles'] = df_PubChem_indolinone_ADMET_temp['smiles']

# %%
df_PubChem_indolinone_ADMET_filtered.to_csv('PubChem_indolinone_ADMET_filtered.csv', index=False)

# %% [markdown]
# ## *Curcumin*

# %%
url = 'https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/ADMET_analysis_p3/PubChem_curcumin_ADMET_p3.csv'
df_PubChem_curcumin_ADMET_p3 = pd.read_csv(url)

# %%
df_PubChem_curcumin_ADMET_temp = Filter(df_PubChem_curcumin_ADMET_p3)
df_PubChem_curcumin_ADMET_filtered = pd.DataFrame()
df_PubChem_curcumin_ADMET_filtered['smiles'] = df_PubChem_curcumin_ADMET_temp['smiles']

# %%
df_PubChem_curcumin_ADMET_filtered.to_csv('PubChem_curcumin_ADMET_filtered.csv', index=False)

# %% [markdown]
# ## *Flavanol*

# %%
url = 'https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/ADMET_analysis_p3/PubChem_flavanol_ADMET_p3.csv'
df_PubChem_flavanol_ADMET_p3 = pd.read_csv(url)

# %%
df_PubChem_flavanol_ADMET_temp = Filter(df_PubChem_flavanol_ADMET_p3)
df_PubChem_flavanol_ADMET_filtered = pd.DataFrame()
df_PubChem_flavanol_ADMET_filtered['smiles'] = df_PubChem_flavanol_ADMET_temp['smiles']

# %%
df_PubChem_flavanol_ADMET_filtered.to_csv('PubChem_flavanol_ADMET_filtered.csv', index=False)

# %% [markdown]
# ## *Stilbene*

# %%
url = 'https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/ADMET_analysis_p3/PubChem_stilbene_ADMET_p3.csv'
df_PubChem_stilbene_ADMET_p3 = pd.read_csv(url)

# %%
df_PubChem_stilbene_ADMET_temp = Filter(df_PubChem_stilbene_ADMET_p3)
df_PubChem_stilbene_ADMET_filtered = pd.DataFrame()
df_PubChem_stilbene_ADMET_filtered['smiles'] = df_PubChem_stilbene_ADMET_temp['smiles']

# %%
df_PubChem_stilbene_ADMET_filtered.to_csv('PubChem_stilbene_ADMET_filtered.csv', index=False)

# %% [markdown]
# # **DrugBank**

# %% [markdown]
# ## *Indolinone*

# %%
url = 'https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/ADMET_analysis_p3/DrugBank_indolinone_ADMET_p3.csv'
df_DrugBank_indolinone_ADMET_p3 = pd.read_csv(url)

# %%
df_DrugBank_indolinone_ADMET_temp = Filter(df_DrugBank_indolinone_ADMET_p3)
df_DrugBank_indolinone_ADMET_filtered = pd.DataFrame()
df_DrugBank_indolinone_ADMET_filtered['smiles'] = df_DrugBank_indolinone_ADMET_temp['smiles']

# %%
df_DrugBank_indolinone_ADMET_filtered.to_csv('DrugBank_indolinone_ADMET_filtered.csv', index=False)

# %% [markdown]
# ## *Curcumin*

# %%
url = 'https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/ADMET_analysis_p3/DrugBank_curcumin_ADMET_p3.csv'
df_DrugBank_curcumin_ADMET_p3 = pd.read_csv(url)

# %%
df_DrugBank_curcumin_ADMET_temp = Filter(df_DrugBank_curcumin_ADMET_p3)
df_DrugBank_curcumin_ADMET_filtered = pd.DataFrame()
df_DrugBank_curcumin_ADMET_filtered['smiles'] = df_DrugBank_curcumin_ADMET_temp['smiles']

# %%
df_DrugBank_curcumin_ADMET_filtered.to_csv('DrugBank_curcumin_ADMET_filtered.csv', index=False)

# %% [markdown]
# ## *Stilbene*

# %%
url = 'https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/ADMET_analysis_p3/DrugBank_stilbene_ADMET_p3.csv'
df_DrugBank_stilbene_ADMET_p3 = pd.read_csv(url)

# %%
df_DrugBank_stilbene_ADMET_temp = Filter(df_DrugBank_stilbene_ADMET_p3)
df_DrugBank_stilbene_ADMET_filtered = pd.DataFrame()
df_DrugBank_stilbene_ADMET_filtered['smiles'] = df_DrugBank_stilbene_ADMET_temp['smiles']

# %%
df_DrugBank_stilbene_ADMET_filtered.to_csv('DrugBank_stilbene_ADMET_filtered.csv', index=False)

# %% [markdown]
# # **UNPD**

# %% [markdown]
# ## *Indolinone*

# %%
url = 'https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/ADMET_analysis_p3/UNPD_indolinone_ADMET_p3.csv'
df_UNPD_indolinone_ADMET_p3 = pd.read_csv(url)

# %%
df_UNPD_indolinone_ADMET_temp = Filter(df_UNPD_indolinone_ADMET_p3)
df_UNPD_indolinone_ADMET_filtered = pd.DataFrame()
df_UNPD_indolinone_ADMET_filtered['smiles'] = df_UNPD_indolinone_ADMET_temp['smiles']

# %%
df_UNPD_indolinone_ADMET_filtered.to_csv('UNPD_indolinone_ADMET_filtered.csv', index=False)

# %% [markdown]
# ## *Curcumin*

# %%
url = 'https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/ADMET_analysis_p3/UNPD_curcumin_ADMET_p3.csv'
df_UNPD_curcumin_ADMET_p3 = pd.read_csv(url)

# %%
df_UNPD_curcumin_ADMET_temp = Filter(df_UNPD_curcumin_ADMET_p3)
df_UNPD_curcumin_ADMET_filtered = pd.DataFrame()
df_UNPD_curcumin_ADMET_filtered['smiles'] = df_UNPD_curcumin_ADMET_temp['smiles']

# %%
df_UNPD_curcumin_ADMET_filtered.to_csv('UNPD_curcumin_ADMET_filtered.csv', index=False)

# %% [markdown]
# ## *Flavanol*

# %%
url = 'https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/ADMET_analysis_p3/UNPD_flavanol_ADMET_p3.csv'
df_UNPD_flavanol_ADMET_p3 = pd.read_csv(url)

# %%
df_UNPD_flavanol_ADMET_temp = Filter(df_UNPD_flavanol_ADMET_p3)
df_UNPD_flavanol_ADMET_filtered = pd.DataFrame()
df_UNPD_flavanol_ADMET_filtered['smiles'] = df_UNPD_flavanol_ADMET_temp['smiles']

# %%
df_UNPD_flavanol_ADMET_filtered.to_csv('UNPD_flavanol_ADMET_filtered.csv', index=False)

# %% [markdown]
# ## *Stilbene*

# %%
url = 'https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/ADMET_analysis_p3/UNPD_stilbene_ADMET_p3.csv'
df_UNPD_stilbene_ADMET_p3 = pd.read_csv(url)

# %%
df_UNPD_stilbene_ADMET_temp = Filter(df_UNPD_stilbene_ADMET_p3)
df_UNPD_stilbene_ADMET_filtered = pd.DataFrame()
df_UNPD_stilbene_ADMET_filtered['smiles'] = df_UNPD_stilbene_ADMET_temp['smiles']

# %%
df_UNPD_stilbene_ADMET_filtered.to_csv('UNPD_stilbene_ADMET_filtered.csv', index=False)

# %% [markdown]
# # **NuBBE**

# %% [markdown]
# ## *Indolinone*

# %%
url = 'https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/ADMET_analysis_p3/NuBBE_indolinone_ADMET_p3.csv'
df_NuBBE_indolinone_ADMET_p3 = pd.read_csv(url)

# %%
df_NuBBE_indolinone_ADMET_temp = Filter(df_NuBBE_indolinone_ADMET_p3)
df_NuBBE_indolinone_ADMET_filtered = pd.DataFrame()
df_NuBBE_indolinone_ADMET_filtered['smiles'] = df_NuBBE_indolinone_ADMET_temp['smiles']

# %%
df_NuBBE_indolinone_ADMET_filtered.to_csv('NuBBE_indolinone_ADMET_filtered.csv', index=False)

# %% [markdown]
# ## *Stilbene*

# %%
url = 'https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/ADMET_analysis_p3/NuBBE_stilbene_ADMET_p3.csv'
df_NuBBE_stilbene_ADMET_p3 = pd.read_csv(url)

# %%
df_NuBBE_stilbene_ADMET_temp = Filter(df_NuBBE_stilbene_ADMET_p3)
df_NuBBE_stilbene_ADMET_filtered = pd.DataFrame()
df_NuBBE_stilbene_ADMET_filtered['smiles'] = df_NuBBE_stilbene_ADMET_temp['smiles']

# %%
df_NuBBE_stilbene_ADMET_filtered.to_csv('NuBBE_stilbene_ADMET_filtered.csv', index=False)

# %%
url = 'https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/ADMET_analysis_p3/PubChem_sulfonamide_ADMET_p3.csv'
df_PubChem_sulfonamide_ADMET_p3 = pd.read_csv(url)

# %%
df_PubChem_sulfonamide_ADMET_p3.describe()
# Out:
#        molecular_weight        logP  hydrogen_bond_acceptors  \
# count        902.000000  902.000000               902.000000
# mean         235.096320    1.473378                 3.157428
# std           35.528344    0.942448                 1.049097
# min          166.220000   -1.827800                 1.000000
# 25%          206.654000    0.816120                 2.000000
# 50%          229.266500    1.497460                 3.000000
# 75%          261.163000    2.173900                 4.000000
# max          368.583000    4.067000                 9.000000
#
#        hydrogen_bond_donors  Lipinski         QED  stereo_centers        tpsa  \
# count            902.000000     902.0  902.000000      902.000000  902.000000
# mean               1.055432       4.0    0.730111        0.127494   66.469568
# std                0.729304       0.0    0.119764        0.505616   21.622105
# min                0.000000       4.0    0.255460        0.000000   17.070000
# ...

# %%
plt.hist(df_PubChem_sulfonamide_ADMET_p3['sa_score'])
# Out:
# (array([133., 318., 213., 142.,  60.,  16.,  11.,   6.,   2.,   1.]),
#  array([1.55358828, 1.89777897, 2.24196966, 2.58616035, 2.93035104,
#         3.27454173, 3.61873243, 3.96292312, 4.30711381, 4.6513045 ,
#         4.99549519]),
#  <BarContainer object of 10 artists>)

# %%
r1a2 = df_PubChem_sulfonamide_ADMET_p3[(df_PubChem_sulfonamide_ADMET_p3['sa_score']>=1) & (df_PubChem_sulfonamide_ADMET_p3['sa_score']<=2)]
r1a2 = r1a2[['smiles','sa_score']]
r1a2.head()
# Out:
#                                  smiles  sa_score
# 0            C1=CC=C(C(=C1)F)S(=O)(=O)N  1.690885
# 1           CNC(=O)OC1=CC=CC2=CC=CC=C21  1.740039
# 2            C1=CC(=CC(=C1)S(=O)(=O)N)F  1.643312
# 3  C1=CC=C2C(=C1)C(=CC=C2O)[N+](=O)[O-]  1.808010
# 4           C1=CC(=C(C=C1F)F)S(=O)(=O)N  1.877638

# %%
mol1 = Chem.MolFromSmiles(r1a2['smiles'][0])
mol2 = Chem.MolFromSmiles(r1a2['smiles'][1])
mol3 = Chem.MolFromSmiles(r1a2['smiles'][2])
mol4 = Chem.MolFromSmiles(r1a2['smiles'][3])
mol5 = Chem.MolFromSmiles(r1a2['smiles'][4])

# %%
Draw.MolToImage(mol1)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %%
Draw.MolToImage(mol2)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %%
Draw.MolToImage(mol3)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %%
Draw.MolToImage(mol4)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %%
Draw.MolToImage(mol5)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %%
r2a3 = df_PubChem_sulfonamide_ADMET_p3[(df_PubChem_sulfonamide_ADMET_p3['sa_score']>=2) & (df_PubChem_sulfonamide_ADMET_p3['sa_score']<=3)]
r2a3 = r2a3[['smiles','sa_score']]
r2a3.head()
# Out:
#                                   smiles  sa_score
# 6   C1=CC2=C(C=CC(=C2N=C1)O)[N+](=O)[O-]  2.077133
# 16        C1=C(C(=CC(=C1F)S(=O)(=O)N)F)F  2.114124
# 17         C1=C(C=NC(=C1Cl)Cl)S(=O)(=O)N  2.267787
# 25           C1=CC2=C(C=CC(=C2N=C1)O)C=O  2.201178
# 31    C1=CC(=C(C=C1C(=O)Cl)S(=O)(=O)N)Cl  2.104246

# %%
mol1 = Chem.MolFromSmiles(r2a3['smiles'][6])
mol2 = Chem.MolFromSmiles(r2a3['smiles'][16])
mol3 = Chem.MolFromSmiles(r2a3['smiles'][17])
mol4 = Chem.MolFromSmiles(r2a3['smiles'][25])
mol5 = Chem.MolFromSmiles(r2a3['smiles'][31])

# %%
Draw.MolToImage(mol1)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %%
Draw.MolToImage(mol2)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %%
Draw.MolToImage(mol3)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %%
Draw.MolToImage(mol4)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %%
Draw.MolToImage(mol5)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %%
url = 'https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/ADMET_analysis_p3/PubChem_indolinone_ADMET_p3.csv'
df_PubChem_indolinone_ADMET_p3 = pd.read_csv(url)
r9a10 = df_PubChem_indolinone_ADMET_p3[(df_PubChem_indolinone_ADMET_p3['sa_score']>=7) & (df_PubChem_indolinone_ADMET_p3['sa_score']<=8)]
r9a10 = r9a10[['smiles','sa_score']]
r9a10.head()
# Out:
#                                                  smiles  sa_score
# 1054  [2H]C1=C(C(=C2C(=C1[2H])C(=C(N2[2H])[2H])[2H])...  7.509118
# 1816  [2H]C1=C(C(=C2C(=C1[2H])C(=C(N2)[2H])[2H])[2H]...  7.176804
# 5161  [2H]C1(C(=CC=C2C1(C(C(C(=O)N2[2H])([2H])[2H])(...  7.316832
# 7336  [2H]C1C=CC=C2C1(C(C(N2[2H])([2H])[2H])([2H])[2...  7.825772
# 8370         C1=C[C@H]2[C@@H]3[C@H]([C@@H]1S2=O)C=CS3=O  7.317774

# %%
plt.hist(df_PubChem_indolinone_ADMET_p3['sa_score'])
# Out:
# (array([ 353., 3264., 3315., 2386., 1363.,  460.,  171.,   48.,   16.,
#           10.]),
#  array([1.23758947, 1.90793403, 2.57827859, 3.24862314, 3.9189677 ,
#         4.58931225, 5.25965681, 5.93000137, 6.60034592, 7.27069048,
#         7.94103504]),
#  <BarContainer object of 10 artists>)

# %%
mol1 = Chem.MolFromSmiles(r9a10['smiles'][1054])
mol2 = Chem.MolFromSmiles(r9a10['smiles'][1816])
mol3 = Chem.MolFromSmiles(r9a10['smiles'][5161])
mol4 = Chem.MolFromSmiles(r9a10['smiles'][7336])
mol5 = Chem.MolFromSmiles(r9a10['smiles'][8370])

# %%
Draw.MolToImage(mol1)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %%
Draw.MolToImage(mol2)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %%
Draw.MolToImage(mol3)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %%
Draw.MolToImage(mol4)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %%
Draw.MolToImage(mol5)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
