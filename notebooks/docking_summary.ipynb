# %% [markdown]
# # **Docking Summary**

# %%
import pandas as pd

# %%
url1 =
url2 =
url3 =
url4 =
url5 =
url6 =
url7 =
url8 =
url9 =
data = pd.read_csv(url1, sep="    ", header=None)
data = pd.read_csv(url2, sep="    ", header=None)
data = pd.read_csv(url3, sep="    ", header=None)
data = pd.read_csv(url4, sep="    ", header=None)
data = pd.read_csv(url5, sep="    ", header=None)
data = pd.read_csv(url6, sep="    ", header=None)
data = pd.read_csv(url7, sep="    ", header=None)
data = pd.read_csv(url8, sep="    ", header=None)
data = pd.read_csv(url9, sep="    ", header=None)
# Out:
# <ipython-input-2-f1f6d4427f18>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   data = pd.read_csv('test.txt', sep="    ", header=None)

# %%
data.head()
# Out:
#                                           0    1
# 0   ./lig_opt_DrugBank_stilbene_1.pdbqt.log -5.2
# 1  ./lig_opt_DrugBank_stilbene_10.pdbqt.log -4.2
# 2  ./lig_opt_DrugBank_stilbene_11.pdbqt.log -5.3
# 3  ./lig_opt_DrugBank_stilbene_12.pdbqt.log -5.8
# 4  ./lig_opt_DrugBank_stilbene_13.pdbqt.log -5.2
