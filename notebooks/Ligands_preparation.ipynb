# %% [markdown]
# # **Ligands Preparation**
#
# Preparing ligands for docking involves several steps to ensure that the ligands are in the correct format and conformation for accurate docking simulations.

# %%
# !apt-get -qq install -y openbabel
# Out:
# Selecting previously unselected package libinchi1.
# (Reading database ... 121913 files and directories currently installed.)
# Preparing to unpack .../libinchi1_1.03+dfsg-4_amd64.deb ...
# Unpacking libinchi1 (1.03+dfsg-4) ...
# Selecting previously unselected package libmaeparser1:amd64.
# Preparing to unpack .../libmaeparser1_1.2.4-1build1_amd64.deb ...
# Unpacking libmaeparser1:amd64 (1.2.4-1build1) ...
# Selecting previously unselected package libopenbabel7.
# Preparing to unpack .../libopenbabel7_3.1.1+dfsg-6ubuntu5_amd64.deb ...
# Unpacking libopenbabel7 (3.1.1+dfsg-6ubuntu5) ...
# Selecting previously unselected package openbabel.
# Preparing to unpack .../openbabel_3.1.1+dfsg-6ubuntu5_amd64.deb ...
# Unpacking openbabel (3.1.1+dfsg-6ubuntu5) ...
# Setting up libmaeparser1:amd64 (1.2.4-1build1) ...
# Setting up libinchi1 (1.03+dfsg-4) ...
# Setting up libopenbabel7 (3.1.1+dfsg-6ubuntu5) ...
# Setting up openbabel (3.1.1+dfsg-6ubuntu5) ...
# ...

# %%
import os

# %% [markdown]
# # **PubChem**

# %% [markdown]
# ## *(4-hydroxynaphthalen-1-yl)sulfonamide*

# %%
# !wget https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/ADMET_filtered/PubChem_sulfonamide_ADMET_filtered.csv
os.rename('PubChem_sulfonamide_ADMET_filtered.csv', 'PubChem_sulfonamide_ADMET_filtered.smi')
# Out:
# --2024-05-27 07:02:00--  https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/ADMET_filtered/PubChem_sulfonamide_ADMET_filtered.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2314 (2.3K) [text/plain]
# Saving to: ‘PubChem_sulfonamide_ADMET_filtered.csv’
#
# PubChem_sulfonamide 100%[===================>]   2.26K  --.-KB/s    in 0s
#
# 2024-05-27 07:02:00 (23.1 MB/s) - ‘PubChem_sulfonamide_ADMET_filtered.csv’ saved [2314/2314]

# %%
# !obabel -i smi PubChem_sulfonamide_ADMET_filtered.smi -o sdf --gen3D > _.sdf
# !obabel -i sdf _.sdf -o mol2 -O PubChem_sulfonamide_.mol2 -h -m
# !obabel *.mol2 -O opt_.xyz --minimize --sd --steps 20000 --ff MMFF94 -p 7.4 --log -m
# !obabel -i xyz *.xyz -o pdbqt -O lig_.pdbqt -m
# !rm *.mol2 *.xyz *.sdf
# !mkdir PubChem_sulfonamide
# !mv *.pdbqt PubChem_sulfonamide
# !zip -r PubChem_sulfonamide.zip PubChem_sulfonamide
# !rm -r PubChem_sulfonamide
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
#  9460    56.18829    56.18918
#  9470    56.17935    56.18026
#  9480    56.17021    56.17113
#  9490    56.16084    56.16179
#  9500    56.15124    56.15222
#  9510    56.14139    56.14239
#  9520    56.13126    56.13228
#  9530    56.12082    56.12188
#  9540    56.11006    56.11116
#  9550    56.09895    56.10008
#  9560    56.08744    56.08861
#  9570    56.07549    56.07671
#  9580    56.06307    56.06434
#  9590    56.05011    56.05144
#  9600    56.03666    56.03799
#  9610    56.02814    56.02874
#  9620    56.02207    56.02268
#  9630    56.01594    56.01656
#  9640    56.00974    56.01037
#  9650    56.00347    56.00410
#  9660    55.99712    55.99776
#  9670    55.99069    55.99134
#  9680    55.98417    55.98482
#  9690    55.97755    55.97822
#  9700    55.97084    55.97152
#  9710    55.96404    55.96472
#  9720    55.95712    55.95782
#  9730    55.95010    55.95081
#  9740    55.94296    55.94368
# ...

# %% [markdown]
# ## *Indolinone*

# %%
# !wget https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/ADMET_filtered/PubChem_indolinone_ADMET_filtered.csv
os.rename('PubChem_indolinone_ADMET_filtered.csv', 'PubChem_indolinone_ADMET_filtered.smi')
# Out:
# --2024-05-28 23:15:54--  https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/ADMET_filtered/PubChem_indolinone_ADMET_filtered.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13870 (14K) [text/plain]
# Saving to: ‘PubChem_indolinone_ADMET_filtered.csv’
#
# PubChem_indolinone_ 100%[===================>]  13.54K  --.-KB/s    in 0s
#
# 2024-05-28 23:15:54 (68.4 MB/s) - ‘PubChem_indolinone_ADMET_filtered.csv’ saved [13870/13870]

# %%
# !obabel -i smi PubChem_indolinone_ADMET_filtered.smi -o sdf --gen3D > _.sdf
# !obabel -i sdf _.sdf -o mol2 -O PubChem_indolinone_.mol2 -h -m
# !obabel *.mol2 -O opt_.xyz --minimize --sd --steps 20000 --ff MMFF94 -p 7.4 --log -m
# !obabel -i xyz *.xyz -o pdbqt -O lig_.pdbqt -m
# !rm *.mol2 *.xyz *.sdf
# !mkdir PubChem_indolinone
# !mv *.pdbqt PubChem_indolinone
# !zip -r PubChem_indolinone.zip PubChem_indolinone
# !rm -r PubChem_indolinone
# Out:
# Streaming output truncated to the last 5000 lines.
#   320    38.17726    38.17727
#   330    38.17723    38.17723
#   340    38.17719    38.17719
#   350    38.17716    38.17716
#   360    38.17713    38.17713
#   370    38.17710    38.17710
#   380    38.17707    38.17707
#   390    38.17704    38.17705
#   400    38.17702    38.17702
#   410    38.17700    38.17700
#   420    38.17697    38.17698
#   430    38.17695    38.17696
#   440    38.17693    38.17694
#   450    38.17692    38.17692
#   460    38.17690    38.17690
#   470    38.17688    38.17688
#   480    38.17687    38.17687
#   490    38.17685    38.17685
#   500    38.17684    38.17684
#   510    38.17683    38.17683
#   520    38.17681    38.17681
#   530    38.17680    38.17680
#   540    38.17679    38.17679
#   550    38.17678    38.17678
#   560    38.17677    38.17677
#     STEEPEST DESCENT HAS CONVERGED
#
# A T O M   T Y P E S
#
# IDX	TYPE	RING
# 1	1	NO
# 2	1	NO
# 3	10	AL
# 4	37	AR
# 5	37	AR
# 6	37	AR
# 7	37	AR
# ...

# %% [markdown]
# ## *Flavanol*

# %%
# !wget https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/ADMET_filtered/PubChem_flavanol_ADMET_filtered.csv
os.rename('PubChem_flavanol_ADMET_filtered.csv', 'PubChem_flavanol_ADMET_filtered.smi')
# Out:
# --2024-05-27 07:52:10--  https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/ADMET_filtered/PubChem_flavanol_ADMET_filtered.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 19270 (19K) [text/plain]
# Saving to: ‘PubChem_flavanol_ADMET_filtered.csv’
#
# PubChem_flavanol_AD 100%[===================>]  18.82K  --.-KB/s    in 0s
#
# 2024-05-27 07:52:10 (95.7 MB/s) - ‘PubChem_flavanol_ADMET_filtered.csv’ saved [19270/19270]

# %%
# !obabel -i smi PubChem_flavanol_ADMET_filtered.smi -o sdf --gen3D > _.sdf
# !obabel -i sdf _.sdf -o mol2 -O PubChem_flavanol_.mol2 -h -m
# !obabel *.mol2 -O opt_.xyz --minimize --sd --steps 20000 --ff MMFF94 -p 7.4 --log -m
# !obabel -i xyz *.xyz -o pdbqt -O lig_.pdbqt -m
# !rm *.mol2 *.xyz *.sdf
# !mkdir PubChem_flavanol
# !mv *.pdbqt PubChem_flavanol
# !zip -r PubChem_flavanol.zip PubChem_flavanol
# !rm -r PubChem_flavanol
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
#  1300    41.61116    41.61122
#  1310    41.61060    41.61066
#  1320    41.61005    41.61010
#  1330    41.60949    41.60955
#  1340    41.60895    41.60900
#  1350    41.60841    41.60846
#  1360    41.60788    41.60793
#  1370    41.60735    41.60740
#  1380    41.60682    41.60688
#  1390    41.60631    41.60636
#  1400    41.60579    41.60584
#  1410    41.60528    41.60533
#  1420    41.60478    41.60483
#  1430    41.60428    41.60433
#  1440    41.60379    41.60384
#  1450    41.60329    41.60334
#  1460    41.60281    41.60286
#  1470    41.60232    41.60237
#  1480    41.60184    41.60189
#  1490    41.60137    41.60141
#  1500    41.60089    41.60094
#  1510    41.60042    41.60047
#  1520    41.59996    41.60000
#  1530    41.59949    41.59954
#  1540    41.59903    41.59908
#  1550    41.59858    41.59862
#  1560    41.59812    41.59817
#  1570    41.59767    41.59772
#  1580    41.59722    41.59727
# ...

# %% [markdown]
# ## *Stilbene*

# %%
# !wget https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/ADMET_filtered/PubChem_stilbene_ADMET_filtered.csv
os.rename('PubChem_stilbene_ADMET_filtered.csv', 'PubChem_stilbene_ADMET_filtered.smi')
# Out:
# --2024-05-28 04:44:47--  https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/ADMET_filtered/PubChem_stilbene_ADMET_filtered.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 254103 (248K) [text/plain]
# Saving to: ‘PubChem_stilbene_ADMET_filtered.csv’
#
# PubChem_stilbene_AD 100%[===================>] 248.15K  --.-KB/s    in 0.003s
#
# 2024-05-28 04:44:47 (73.4 MB/s) - ‘PubChem_stilbene_ADMET_filtered.csv’ saved [254103/254103]

# %%
# !obabel -i smi PubChem_stilbene_ADMET_filtered.smi -o sdf --gen3D > _.sdf
# !obabel -i sdf _.sdf -o mol2 -O PubChem_stilbene_.mol2 -h -m
# !obabel *.mol2 -O opt_.xyz --minimize --sd --steps 20000 --ff MMFF94 -p 7.4 --log -m
# !obabel -i xyz *.xyz -o pdbqt -O lig_.pdbqt -m
# !rm *.mol2 *.xyz *.sdf
# !mkdir PubChem_stilbene
# !mv *.pdbqt PubChem_stilbene
# !zip -r PubChem_stilbene.zip PubChem_stilbene
# !rm -r PubChem_stilbene
# Out:
# Streaming output truncated to the last 5000 lines.
#  19300    29.19302    29.19303
#  19310    29.19289    29.19290
#  19320    29.19275    29.19277
#  19330    29.19261    29.19262
#  19340    29.19247    29.19248
#  19350    29.19240    29.19241
#  19360    29.19234    29.19234
#  19370    29.19227    29.19228
#  19380    29.19220    29.19221
#  19390    29.19213    29.19214
#  19400    29.19206    29.19206
#  19410    29.19198    29.19199
#  19420    29.19190    29.19191
#  19430    29.19182    29.19183
#  19440    29.19174    29.19175
#  19450    29.19166    29.19167
#  19460    29.19157    29.19158
#  19470    29.19148    29.19149
#  19480    29.19138    29.19139
#  19490    29.19128    29.19129
#  19500    29.19118    29.19119
#  19510    29.19107    29.19108
#  19520    29.19095    29.19096
#  19530    29.19083    29.19084
#  19540    29.19070    29.19071
#  19550    29.19056    29.19057
#  19560    29.19049    29.19050
#  19570    29.19043    29.19044
# ...

# %% [markdown]
# # **DrugBank**

# %% [markdown]
# ## *Indolinone*

# %%
# !wget https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/ADMET_filtered/DrugBank_indolinone_ADMET_filtered.csv
os.rename('DrugBank_indolinone_ADMET_filtered.csv', 'DrugBank_indolinone_ADMET_filtered.smi')
# Out:
# --2024-05-27 06:28:01--  https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/ADMET_filtered/DrugBank_indolinone_ADMET_filtered.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1397 (1.4K) [text/plain]
# Saving to: ‘DrugBank_indolinone_ADMET_filtered.csv’
#
# DrugBank_indolinone 100%[===================>]   1.36K  --.-KB/s    in 0s
#
# 2024-05-27 06:28:01 (15.3 MB/s) - ‘DrugBank_indolinone_ADMET_filtered.csv’ saved [1397/1397]

# %%
# !obabel -i smi DrugBank_indolinone_ADMET_filtered.smi -o sdf --gen3D > _.sdf
# !obabel -i sdf _.sdf -o mol2 -O DrugBank_indolinone_.mol2 -h -m
# !obabel *.mol2 -O opt_.xyz --minimize --sd --steps 20000 --ff MMFF94 -p 7.4 --log -m
# !obabel -i xyz *.xyz -o pdbqt -O lig_.pdbqt -m
# !rm *.mol2 *.xyz *.sdf
# !mkdir DrugBank_indolinone
# !mv *.pdbqt DrugBank_indolinone
# !zip -r DrugBank_indolinone.zip DrugBank_indolinone
# !rm -r DrugBank_indolinone
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
#  10500    27.59025    27.59028
#  10510    27.59002    27.59005
#  10520    27.58979    27.58981
#  10530    27.58955    27.58958
#  10540    27.58931    27.58934
#  10550    27.58907    27.58910
#  10560    27.58883    27.58886
#  10570    27.58859    27.58861
#  10580    27.58835    27.58837
#  10590    27.58810    27.58812
#  10600    27.58785    27.58787
#  10610    27.58760    27.58762
#  10620    27.58734    27.58737
#  10630    27.58709    27.58711
#  10640    27.58682    27.58685
#  10650    27.58656    27.58658
#  10660    27.58629    27.58632
#  10670    27.58602    27.58605
#  10680    27.58574    27.58577
#  10690    27.58546    27.58549
#  10700    27.58518    27.58521
#  10710    27.58489    27.58492
#  10720    27.58460    27.58463
#  10730    27.58430    27.58433
#  10740    27.58399    27.58402
#  10750    27.58368    27.58371
#  10760    27.58336    27.58340
#  10770    27.58303    27.58307
# ...

# %% [markdown]
# ## *Stilbene*

# %%
# !wget https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/ADMET_filtered/DrugBank_stilbene_ADMET_filtered.csv
os.rename('DrugBank_stilbene_ADMET_filtered.csv', 'DrugBank_stilbene_ADMET_filtered.smi')
# Out:
# --2024-05-27 06:31:44--  https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/ADMET_filtered/DrugBank_stilbene_ADMET_filtered.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 769 [text/plain]
# Saving to: ‘DrugBank_stilbene_ADMET_filtered.csv’
#
# DrugBank_stilbene_A 100%[===================>]     769  --.-KB/s    in 0s
#
# 2024-05-27 06:31:44 (38.9 MB/s) - ‘DrugBank_stilbene_ADMET_filtered.csv’ saved [769/769]

# %%
# !obabel -i smi DrugBank_stilbene_ADMET_filtered.smi -o sdf --gen3D > _.sdf
# !obabel -i sdf _.sdf -o mol2 -O DrugBank_stilbene_.mol2 -h -m
# !obabel *.mol2 -O opt_.xyz --minimize --sd --steps 20000 --ff MMFF94 -p 7.4 --log -m
# !obabel -i xyz *.xyz -o pdbqt -O lig_.pdbqt -m
# !rm *.mol2 *.xyz *.sdf
# !mkdir DrugBank_stilbene
# !mv *.pdbqt DrugBank_stilbene
# !zip -r DrugBank_stilbene.zip DrugBank_stilbene
# !rm -r DrugBank_stilbene
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
#  14540    77841995171.59698    77841995171.59698
#  14550    77841995171.59698    77841995171.59698
#  14560    77841995171.59698    77841995171.59698
#  14570    77841995171.59698    77841995171.59698
#  14580    77841995171.59698    77841995171.59698
#  14590    77841995171.59698    77841995171.59698
#  14600    77841995171.59698    77841995171.59698
#  14610    77841995171.59698    77841995171.59698
#  14620    77841995171.59698    77841995171.59698
#  14630    77841995171.59698    77841995171.59698
#  14640    77841995171.59698    77841995171.59698
#  14650    77841995171.59698    77841995171.59698
#  14660    77841995171.59698    77841995171.59698
#  14670    77841995171.59698    77841995171.59698
#  14680    77841995171.59698    77841995171.59698
#  14690    77841995171.59698    77841995171.59698
#  14700    77841995171.59698    77841995171.59698
#  14710    77841995171.59698    77841995171.59698
# ...

# %% [markdown]
# # **UNPD**

# %% [markdown]
# ## *Indolinone*

# %%
# !wget https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/ADMET_filtered/UNPD_indolinone_ADMET_filtered.csv
os.rename('UNPD_indolinone_ADMET_filtered.csv', 'UNPD_indolinone_ADMET_filtered.smi')
# Out:
# --2024-05-27 06:42:21--  https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/ADMET_filtered/UNPD_indolinone_ADMET_filtered.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2155 (2.1K) [text/plain]
# Saving to: ‘UNPD_indolinone_ADMET_filtered.csv’
#
# UNPD_indolinone_ADM 100%[===================>]   2.10K  --.-KB/s    in 0s
#
# 2024-05-27 06:42:21 (22.6 MB/s) - ‘UNPD_indolinone_ADMET_filtered.csv’ saved [2155/2155]

# %%
# !obabel -i smi UNPD_indolinone_ADMET_filtered.smi -o sdf --gen3D > _.sdf
# !obabel -i sdf _.sdf -o mol2 -O UNPD_indolinone_.mol2 -h -m
# !obabel *.mol2 -O opt_.xyz --minimize --sd --steps 20000 --ff MMFF94 -p 7.4 --log -m
# !obabel -i xyz *.xyz -o pdbqt -O lig_.pdbqt -m
# !rm *.mol2 *.xyz *.sdf
# !mkdir UNPD_indolinone
# !mv *.pdbqt UNPD_indolinone
# !zip -r UNPD_indolinone.zip UNPD_indolinone
# !rm -r UNPD_indolinone
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
# 27	37	AR
# 28	28	NO
# 29	5	NO
# 30	5	NO
# 31	5	NO
# 32	5	NO
# 33	5	NO
# 34	5	NO
# 35	5	NO
# 36	5	NO
# 37	28	NO
# 38	5	NO
# 39	5	NO
# 40	5	NO
# 41	5	NO
#
# F O R M A L   C H A R G E S
#
# IDX	CHARGE
# 1	0.000000
# 2	0.000000
# 3	0.000000
# 4	0.000000
# 5	0.000000
# 6	0.000000
# 7	0.000000
# 8	0.000000
# 9	0.000000
# 10	0.000000
# 11	0.000000
# 12	0.000000
# 13	0.000000
# 14	0.000000
# 15	0.000000
# 16	0.000000
# 17	0.000000
# 18	0.000000
# 19	0.000000
# 20	0.000000
# 21	0.000000
# 22	0.000000
# 23	0.000000
# 24	0.000000
# 25	0.000000
# 26	0.000000
# 27	0.000000
# 28	0.000000
# 29	0.000000
# 30	0.000000
# 31	0.000000
# 32	0.000000
# 33	0.000000
# 34	0.000000
# 35	0.000000
# 36	0.000000
# 37	0.000000
# 38	0.000000
# 39	0.000000
# 40	0.000000
# 41	0.000000
#
# P A R T I A L   C H A R G E S
#
# IDX	CHARGE
# 1	-0.570000
# 2	0.569000
# 3	-0.730100
# 4	0.361100
# 5	0.449000
# 6	-0.629000
# 7	0.179000
# 8	-0.150000
# ...

# %% [markdown]
# ## *Flavanol*

# %%
# !wget https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/ADMET_filtered/UNPD_flavanol_ADMET_filtered.csv
os.rename('UNPD_flavanol_ADMET_filtered.csv', 'UNPD_flavanol_ADMET_filtered.smi')
# Out:
# --2024-05-27 06:48:13--  https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/ADMET_filtered/UNPD_flavanol_ADMET_filtered.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 119 [text/plain]
# Saving to: ‘UNPD_flavanol_ADMET_filtered.csv’
#
# UNPD_flavanol_ADMET 100%[===================>]     119  --.-KB/s    in 0s
#
# 2024-05-27 06:48:13 (1.86 MB/s) - ‘UNPD_flavanol_ADMET_filtered.csv’ saved [119/119]

# %%
# !obabel -i smi UNPD_flavanol_ADMET_filtered.smi -o sdf --gen3D > _.sdf
# !obabel -i sdf _.sdf -o mol2 -O UNPD_flavanol_.mol2 -h -m
# !obabel *.mol2 -O opt_.xyz --minimize --sd --steps 20000 --ff MMFF94 -p 7.4 --log -m
# !obabel -i xyz *.xyz -o pdbqt -O lig_.pdbqt -m
# !rm *.mol2 *.xyz *.sdf
# !mkdir UNPD_flavanol
# !mv *.pdbqt UNPD_flavanol
# !zip -r UNPD_flavanol.zip UNPD_flavanol
# !rm -r UNPD_flavanol
# Out:
# 3 molecules converted
# 3 molecules converted
# 3 files output. The first is UNPD_flavanol_1.mol2
#
# A T O M   T Y P E S
#
# IDX	TYPE	RING
# 1	1	NO
# 2	6	NO
# 3	37	AR
# 4	37	AR
# 5	1	AL
# 6	6	NO
# 7	1	AL
# 8	1	AL
# 9	6	NO
# 10	1	NO
# 11	6	AL
# 12	37	AR
# 13	37	AR
# 14	63	AR
# 15	59	AR
# 16	63	AR
# 17	64	AR
# 18	64	AR
# 19	37	AR
# 20	37	AR
# 21	37	AR
# 22	37	AR
# 23	37	AR
# 24	37	AR
# 25	5	NO
# 26	5	NO
# 27	5	NO
# 28	5	NO
# 29	21	NO
# 30	5	NO
# 31	5	NO
# 32	5	NO
# 33	5	NO
# 34	5	NO
# 35	5	NO
# 36	5	NO
# 37	5	NO
# 38	5	NO
# 39	5	NO
# 40	5	NO
# 41	5	NO
# 42	5	NO
#
# F O R M A L   C H A R G E S
#
# IDX	CHARGE
# 1	0.000000
# 2	0.000000
# 3	0.000000
# 4	0.000000
# 5	0.000000
# 6	0.000000
# 7	0.000000
# 8	0.000000
# 9	0.000000
# 10	0.000000
# 11	0.000000
# 12	0.000000
# 13	0.000000
# 14	0.000000
# 15	0.000000
# 16	0.000000
# 17	0.000000
# 18	0.000000
# 19	0.000000
# 20	0.000000
# 21	0.000000
# 22	0.000000
# 23	0.000000
# 24	0.000000
# 25	0.000000
# 26	0.000000
# 27	0.000000
# 28	0.000000
# ...

# %% [markdown]
# ## *Stilbene*

# %%
# !wget https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/ADMET_filtered/UNPD_stilbene_ADMET_filtered.csv
os.rename('UNPD_stilbene_ADMET_filtered.csv', 'UNPD_stilbene_ADMET_filtered.smi')
# Out:
# --2024-05-27 06:48:51--  https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/ADMET_filtered/UNPD_stilbene_ADMET_filtered.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4000 (3.9K) [text/plain]
# Saving to: ‘UNPD_stilbene_ADMET_filtered.csv’
#
# UNPD_stilbene_ADMET 100%[===================>]   3.91K  --.-KB/s    in 0s
#
# 2024-05-27 06:48:51 (53.9 MB/s) - ‘UNPD_stilbene_ADMET_filtered.csv’ saved [4000/4000]

# %%
# !obabel -i smi UNPD_stilbene_ADMET_filtered.smi -o sdf --gen3D > _.sdf
# !obabel -i sdf _.sdf -o mol2 -O UNPD_stilbene_.mol2 -h -m
# !obabel *.mol2 -O opt_.xyz --minimize --sd --steps 20000 --ff MMFF94 -p 7.4 --log -m
# !obabel -i xyz *.xyz -o pdbqt -O lig_.pdbqt -m
# !rm *.mol2 *.xyz *.sdf
# !mkdir UNPD_stilbene
# !mv *.pdbqt UNPD_stilbene
# !zip -r UNPD_stilbene.zip UNPD_stilbene
# !rm -r UNPD_stilbene
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
#  2220    52.59619    52.59630
#  2230    52.59510    52.59522
#  2240    52.59390    52.59403
#  2250    52.59247    52.59263
#  2260    52.59067    52.59088
#  2270    52.58815    52.58846
#  2280    52.58407    52.58462
#  2290    52.57698    52.57714
#  2300    52.57601    52.57611
#  2310    52.57500    52.57510
#  2320    52.57384    52.57396
#  2330    52.57242    52.57258
#  2340    52.57055    52.57077
#  2350    52.56776    52.56812
#  2360    52.56270    52.56344
#  2370    52.55807    52.55816
#  2380    52.55726    52.55734
#  2390    52.55639    52.55648
#  2400    52.55541    52.55552
#  2410    52.55425    52.55438
#  2420    52.55274    52.55292
#  2430    52.55057    52.55084
#  2440    52.54688    52.54739
#  2450    52.54174    52.54181
#  2460    52.54103    52.54110
#  2470    52.54029    52.54037
#  2480    52.53947    52.53956
#  2490    52.53851    52.53862
#  2500    52.53730    52.53744
# ...

# %% [markdown]
# # **Control**
#
# Gallic acid: -4.9 kcal/mol "C1=C(C=C(C(=C1O)O)O)C(=O)O"
# Metaproterenol: -4.6 kcal/mol "CC(C)NCC(C1=CC(=CC(=C1)O)O)O"
# Clenbuterol: -3.9 kcal/mol "CC(C)(C)NCC(C1=CC(=C(C(=C1)Cl)N)Cl)O"
# Salbutamol: -4.1 kcal/mol "CC(C)(C)NCC(C1=CC(=C(C=C1)O)CO)O"

# %%
import pandas as pd

# %%
control = pd.DataFrame(["C1=C(C=C(C(=C1O)O)O)C(=O)O",
                        "CC(C)NCC(C1=CC(=CC(=C1)O)O)O",
                        "CC(C)(C)NCC(C1=CC(=C(C(=C1)Cl)N)Cl)O",
                        "CC(C)(C)NCC(C1=CC(=C(C=C1)O)CO)O"])
control.to_csv("control.csv", sep="," , index=False, header=False)
os.rename('control.csv', 'control.smi')

# %%
# !obabel -i smi control.smi -o sdf --gen3D > _.sdf
# !obabel -i sdf _.sdf -o mol2 -O control_.mol2 -h -m
# !obabel *.mol2 -O opt_.xyz --minimize --sd --steps 20000 --ff MMFF94 -p 7.4 --log -m
# !obabel -i xyz *.xyz -o pdbqt -O lig_.pdbqt -m
# !rm *.mol2 *.xyz *.sdf
# !mkdir control
# !mv *.pdbqt control
# !zip -r control.zip control
# !rm -r control
# Out:
# 4 molecules converted
# 4 molecules converted
# 4 files output. The first is control_1.mol2
#
# A T O M   T Y P E S
#
# IDX	TYPE	RING
# 1	37	AR
# 2	37	AR
# 3	37	AR
# 4	37	AR
# 5	37	AR
# 6	37	AR
# 7	6	NO
# 8	6	NO
# 9	6	NO
# 10	3	NO
# 11	7	NO
# 12	6	NO
# 13	5	NO
# 14	5	NO
# 15	29	NO
# 16	29	NO
# 17	29	NO
# 18	24	NO
#
# F O R M A L   C H A R G E S
#
# IDX	CHARGE
# 1	0.000000
# 2	0.000000
# 3	0.000000
# 4	0.000000
# 5	0.000000
# 6	0.000000
# 7	0.000000
# 8	0.000000
# 9	0.000000
# 10	0.000000
# 11	0.000000
# 12	0.000000
# 13	0.000000
# 14	0.000000
# 15	0.000000
# 16	0.000000
# 17	0.000000
# 18	0.000000
#
# P A R T I A L   C H A R G E S
#
# IDX	CHARGE
# 1	-0.150000
# 2	0.086200
# 3	-0.150000
# 4	0.082500
# 5	0.082500
# 6	0.082500
# 7	-0.532500
# 8	-0.532500
# 9	-0.532500
# 10	0.633800
# 11	-0.570000
# 12	-0.650000
# 13	0.150000
# 14	0.150000
# 15	0.450000
# 16	0.450000
# 17	0.450000
# 18	0.500000
#
# S E T T I N G   U P   C A L C U L A T I O N S
#
# SETTING UP BOND CALCULATIONS...
# ...
