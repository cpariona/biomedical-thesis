# %%
# !pip install rdkit-pypi
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.4/29.4 MB 15.8 MB/s eta 0:00:00
# ...

# %%
from rdkit import Chem
from rdkit.Chem import Draw
from rdkit.Chem.Draw import IPythonConsole
import pandas as pd

# %%
# !wget https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/ADMET_analysis_p2/pains.txt
inf = open('pains.txt', "r")
sub_strct = [ line.rstrip().split(" ") for line in inf ]

smarts = [ line[0] for line in sub_strct]
desc = [ line[1] for line in sub_strct]
dic = dict(zip(smarts, desc))

def pains_filt(smiles):

    mol = Chem.MolFromSmiles(smiles)

    for k,v in dic.items():
        subs = Chem.MolFromSmarts( k )
        if subs != None:
            if mol.HasSubstructMatch( subs ):
                mol.SetProp(v,k)

    props = [prop for prop in mol.GetPropNames()]

    return props
# Out:
# --2024-05-17 20:40:44--  https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/ADMET_analysis_p2/pains.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 55457 (54K) [text/plain]
# Saving to: ‘pains.txt.3’
#
# pains.txt.3         100%[===================>]  54.16K  --.-KB/s    in 0.02s
#
# 2024-05-17 20:40:44 (2.92 MB/s) - ‘pains.txt.3’ saved [55457/55457]

# %% [markdown]
# # **PubChem**

# %% [markdown]
# ## *(4-hydroxynaphthalen-1-yl)sulfonamide*

# %%
url = 'https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/ADMET_analysis_p1/PubChem_sulfonamide_ADMET_p1.csv'
df_PubChem_sulfonamide_ADMET_p1 = pd.read_csv(url)

# %%
df_PubChem_sulfonamide_ADMET_p1['PAINS'] = [pains_filt(df_PubChem_sulfonamide_ADMET_p1['smiles'][i]) for i in range(len(df_PubChem_sulfonamide_ADMET_p1['smiles']))]

# %%
df_PubChem_sulfonamide_ADMET_p1.to_csv('PubChem_sulfonamide_ADMET_p2.csv', index=False)

# %% [markdown]
# ## *Indolinone*

# %%
url = 'https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/ADMET_analysis_p1/PubChem_indolinone_ADMET_p1.csv'
df_PubChem_indolinone_ADMET_p1 = pd.read_csv(url)

# %%
df_PubChem_indolinone_ADMET_p1['PAINS'] = [pains_filt(df_PubChem_indolinone_ADMET_p1['smiles'][i]) for i in range(len(df_PubChem_indolinone_ADMET_p1['smiles']))]

# %%
df_PubChem_indolinone_ADMET_p1.to_csv('PubChem_indolinone_ADMET_p2.csv', index=False)

# %% [markdown]
# ## *Curcumin*

# %%
url = 'https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/ADMET_analysis_p1/PubChem_curcumin_ADMET_p1.csv'
df_PubChem_curcumin_ADMET_p1 = pd.read_csv(url)

# %%
df_PubChem_curcumin_ADMET_p1['PAINS'] = [pains_filt(df_PubChem_curcumin_ADMET_p1['smiles'][i]) for i in range(len(df_PubChem_curcumin_ADMET_p1['smiles']))]

# %%
df_PubChem_curcumin_ADMET_p1.to_csv('PubChem_curcumin_ADMET_p2.csv', index=False)

# %% [markdown]
# ## *Flavanol*

# %%
url = 'https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/ADMET_analysis_p1/PubChem_flavanol_ADMET_p1.csv'
df_PubChem_flavanol_ADMET_p1 = pd.read_csv(url)

# %%
df_PubChem_flavanol_ADMET_p1['PAINS'] = [pains_filt(df_PubChem_flavanol_ADMET_p1['smiles'][i]) for i in range(len(df_PubChem_flavanol_ADMET_p1['smiles']))]

# %%
df_PubChem_flavanol_ADMET_p1.to_csv('PubChem_flavanol_ADMET_p2.csv', index=False)

# %% [markdown]
# ## *Stilbene*

# %%
url = 'https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/ADMET_analysis_p1/PubChem_stilbene_ADMET_p1.csv'
df_PubChem_stilbene_ADMET_p1 = pd.read_csv(url)

# %%
df_PubChem_stilbene_ADMET_p1['PAINS'] = [pains_filt(df_PubChem_stilbene_ADMET_p1['smiles'][i]) for i in range(len(df_PubChem_stilbene_ADMET_p1['smiles']))]

# %%
df_PubChem_stilbene_ADMET_p1.to_csv('PubChem_stilbene_ADMET_p2.csv', index=False)

# %% [markdown]
# # **DrugBank**

# %% [markdown]
# ## *Indolinone*

# %%
url = 'https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/ADMET_analysis_p1/DrugBank_indolinone_ADMET_p1.csv'
df_DrugBank_indolinone_ADMET_p1 = pd.read_csv(url)

# %%
df_DrugBank_indolinone_ADMET_p1['PAINS'] = [pains_filt(df_DrugBank_indolinone_ADMET_p1['smiles'][i]) for i in range(len(df_DrugBank_indolinone_ADMET_p1['smiles']))]

# %%
df_DrugBank_indolinone_ADMET_p1.to_csv('DrugBank_indolinone_ADMET_p2.csv', index=False)

# %% [markdown]
# ## *Curcumin*

# %%
url = 'https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/ADMET_analysis_p1/DrugBank_curcumin_ADMET_p1.csv'
df_DrugBank_curcumin_ADMET_p1 = pd.read_csv(url)

# %%
df_DrugBank_curcumin_ADMET_p1['PAINS'] = [pains_filt(df_DrugBank_curcumin_ADMET_p1['smiles'][i]) for i in range(len(df_DrugBank_curcumin_ADMET_p1['smiles']))]

# %%
df_DrugBank_curcumin_ADMET_p1.to_csv('DrugBank_curcumin_ADMET_p2.csv', index=False)

# %% [markdown]
# ## *Stilbene*

# %%
url = 'https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/ADMET_analysis_p1/DrugBank_stilbene_ADMET_p1.csv'
df_DrugBank_stilbene_ADMET_p1 = pd.read_csv(url)

# %%
df_DrugBank_stilbene_ADMET_p1['PAINS'] = [pains_filt(df_DrugBank_stilbene_ADMET_p1['smiles'][i]) for i in range(len(df_DrugBank_stilbene_ADMET_p1['smiles']))]

# %%
df_DrugBank_stilbene_ADMET_p1.to_csv('DrugBank_stilbene_ADMET_p2.csv', index=False)

# %% [markdown]
# # **UNPD**

# %% [markdown]
# ## *Indolinone*

# %%
url = 'https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/ADMET_analysis_p1/UNPD_indolinone_ADMET_p1.csv'
df_UNPD_indolinone_ADMET_p1 = pd.read_csv(url)

# %%
df_UNPD_indolinone_ADMET_p1['PAINS'] = [pains_filt(df_UNPD_indolinone_ADMET_p1['smiles'][i]) for i in range(len(df_UNPD_indolinone_ADMET_p1['smiles']))]

# %%
df_UNPD_indolinone_ADMET_p1.to_csv('UNPD_indolinone_ADMET_p2.csv', index=False)

# %% [markdown]
# ## *Curcumin*

# %%
url = 'https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/ADMET_analysis_p1/UNPD_curcumin_ADMET_p1.csv'
df_UNPD_curcumin_ADMET_p1 = pd.read_csv(url)

# %%
df_UNPD_curcumin_ADMET_p1['PAINS'] = [pains_filt(df_UNPD_curcumin_ADMET_p1['smiles'][i]) for i in range(len(df_UNPD_curcumin_ADMET_p1['smiles']))]

# %%
df_UNPD_curcumin_ADMET_p1.to_csv('UNPD_curcumin_ADMET_p2.csv', index=False)

# %% [markdown]
# ## *Flavanol*

# %%
url = 'https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/ADMET_analysis_p1/UNPD_flavanol_ADMET_p1.csv'
df_UNPD_flavanol_ADMET_p1 = pd.read_csv(url)

# %%
df_UNPD_flavanol_ADMET_p1['PAINS'] = [pains_filt(df_UNPD_flavanol_ADMET_p1['smiles'][i]) for i in range(len(df_UNPD_flavanol_ADMET_p1['smiles']))]

# %%
df_UNPD_flavanol_ADMET_p1.to_csv('UNPD_flavanol_ADMET_p2.csv', index=False)

# %% [markdown]
# ## *Stilbene*

# %%
url = 'https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/ADMET_analysis_p1/UNPD_stilbene_ADMET_p1.csv'
df_UNPD_stilbene_ADMET_p1 = pd.read_csv(url)

# %%
df_UNPD_stilbene_ADMET_p1['PAINS'] = [pains_filt(df_UNPD_stilbene_ADMET_p1['smiles'][i]) for i in range(len(df_UNPD_stilbene_ADMET_p1['smiles']))]

# %%
df_UNPD_stilbene_ADMET_p1.to_csv('UNPD_stilbene_ADMET_p2.csv', index=False)

# %% [markdown]
# # **NuBBE**

# %% [markdown]
# ## *Indolinone*

# %%
url = 'https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/ADMET_analysis_p1/NuBBE_indolinone_ADMET_p1.csv'
df_NuBBE_indolinone_ADMET_p1 = pd.read_csv(url)

# %%
df_NuBBE_indolinone_ADMET_p1['PAINS'] = [pains_filt(df_NuBBE_indolinone_ADMET_p1['smiles'][i]) for i in range(len(df_NuBBE_indolinone_ADMET_p1['smiles']))]

# %%
df_NuBBE_indolinone_ADMET_p1.to_csv('NuBBE_indolinone_ADMET_p2.csv', index=False)

# %% [markdown]
# ## *Stilbene*

# %%
url = 'https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/ADMET_analysis_p1/NuBBE_stilbene_ADMET_p1.csv'
df_NuBBE_stilbene_ADMET_p1 = pd.read_csv(url)

# %%
df_NuBBE_stilbene_ADMET_p1['PAINS'] = [pains_filt(df_NuBBE_stilbene_ADMET_p1['smiles'][i]) for i in range(len(df_NuBBE_stilbene_ADMET_p1['smiles']))]

# %%
df_NuBBE_stilbene_ADMET_p1.to_csv('NuBBE_stilbene_ADMET_p2.csv', index=False)
