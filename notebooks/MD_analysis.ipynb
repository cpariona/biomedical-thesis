# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Download files
# !wget https://raw.githubusercontent.com/cpariona/biomedical-thesis/refs/heads/main/data/MD_results/2_Protein_UNPD_indolinone_41_100ns_310K_150mM-data/PL_RMSD.dat
# !wget https://raw.githubusercontent.com/cpariona/biomedical-thesis/refs/heads/main/data/MD_results/3_Protein_UNPD_indolinone_42_100ns_310K_150mM-data/PL_RMSD.dat
# !wget https://raw.githubusercontent.com/cpariona/biomedical-thesis/refs/heads/main/data/MD_results/4_Protein_UNPD_indolinona_27_100ns_310K_150mM-data/PL_RMSD.dat
# !wget https://raw.githubusercontent.com/cpariona/biomedical-thesis/refs/heads/main/data/MD_results/2_Protein_UNPD_indolinone_41_100ns_310K_150mM-data/L-Properties.dat
# !wget https://raw.githubusercontent.com/cpariona/biomedical-thesis/refs/heads/main/data/MD_results/3_Protein_UNPD_indolinone_42_100ns_310K_150mM-data/L-Properties.dat
# !wget https://raw.githubusercontent.com/cpariona/biomedical-thesis/refs/heads/main/data/MD_results/4_Protein_UNPD_indolinona_27_100ns_310K_150mM-data/L-Properties.dat
# !wget https://raw.githubusercontent.com/cpariona/biomedical-thesis/refs/heads/main/data/MD_results/2_Protein_UNPD_indolinone_41_100ns_310K_150mM-data/P_RMSF.dat
# !wget https://raw.githubusercontent.com/cpariona/biomedical-thesis/refs/heads/main/data/MD_results/3_Protein_UNPD_indolinone_42_100ns_310K_150mM-data/P_RMSF.dat
# !wget https://raw.githubusercontent.com/cpariona/biomedical-thesis/refs/heads/main/data/MD_results/4_Protein_UNPD_indolinona_27_100ns_310K_150mM-data/P_RMSF.dat
# Out:
# --2025-02-28 22:43:55--  https://raw.githubusercontent.com/cpariona/biomedical-thesis/refs/heads/main/data/MD_results/2_Protein_UNPD_indolinone_41_100ns_310K_150mM-data/PL_RMSD.dat
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 102204 (100K) [text/plain]
# Saving to: ‘PL_RMSD.dat’
#
# PL_RMSD.dat         100%[===================>]  99.81K  --.-KB/s    in 0.004s
#
# 2025-02-28 22:43:55 (21.9 MB/s) - ‘PL_RMSD.dat’ saved [102204/102204]
#
# --2025-02-28 22:43:56--  https://raw.githubusercontent.com/cpariona/biomedical-thesis/refs/heads/main/data/MD_results/3_Protein_UNPD_indolinone_42_100ns_310K_150mM-data/PL_RMSD.dat
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 102204 (100K) [text/plain]
# Saving to: ‘PL_RMSD.dat.1’
#
# PL_RMSD.dat.1       100%[===================>]  99.81K  --.-KB/s    in 0.006s
#
# 2025-02-28 22:43:56 (17.6 MB/s) - ‘PL_RMSD.dat.1’ saved [102204/102204]
#
# --2025-02-28 22:43:56--  https://raw.githubusercontent.com/cpariona/biomedical-thesis/refs/heads/main/data/MD_results/4_Protein_UNPD_indolinona_27_100ns_310K_150mM-data/PL_RMSD.dat
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 102204 (100K) [text/plain]
# Saving to: ‘PL_RMSD.dat.2’
#
# PL_RMSD.dat.2       100%[===================>]  99.81K  --.-KB/s    in 0.004s
#
# 2025-02-28 22:43:56 (27.3 MB/s) - ‘PL_RMSD.dat.2’ saved [102204/102204]
#
# --2025-02-28 22:43:56--  https://raw.githubusercontent.com/cpariona/biomedical-thesis/refs/heads/main/data/MD_results/2_Protein_UNPD_indolinone_41_100ns_310K_150mM-data/L-Properties.dat
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 88176 (86K) [text/plain]
# Saving to: ‘L-Properties.dat’
#
# L-Properties.dat    100%[===================>]  86.11K  --.-KB/s    in 0.004s
#
# 2025-02-28 22:43:57 (19.8 MB/s) - ‘L-Properties.dat’ saved [88176/88176]
#
# --2025-02-28 22:43:57--  https://raw.githubusercontent.com/cpariona/biomedical-thesis/refs/heads/main/data/MD_results/3_Protein_UNPD_indolinone_42_100ns_310K_150mM-data/L-Properties.dat
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 88176 (86K) [text/plain]
# Saving to: ‘L-Properties.dat.1’
#
# L-Properties.dat.1  100%[===================>]  86.11K  --.-KB/s    in 0.004s
#
# 2025-02-28 22:43:57 (21.9 MB/s) - ‘L-Properties.dat.1’ saved [88176/88176]
#
# --2025-02-28 22:43:57--  https://raw.githubusercontent.com/cpariona/biomedical-thesis/refs/heads/main/data/MD_results/4_Protein_UNPD_indolinona_27_100ns_310K_150mM-data/L-Properties.dat
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 88176 (86K) [text/plain]
# Saving to: ‘L-Properties.dat.2’
#
# L-Properties.dat.2  100%[===================>]  86.11K  --.-KB/s    in 0.003s
#
# 2025-02-28 22:43:57 (24.7 MB/s) - ‘L-Properties.dat.2’ saved [88176/88176]
#
# --2025-02-28 22:43:57--  https://raw.githubusercontent.com/cpariona/biomedical-thesis/refs/heads/main/data/MD_results/2_Protein_UNPD_indolinone_41_100ns_310K_150mM-data/P_RMSF.dat
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 15082 (15K) [text/plain]
# Saving to: ‘P_RMSF.dat’
#
# P_RMSF.dat          100%[===================>]  14.73K  --.-KB/s    in 0s
#
# 2025-02-28 22:43:57 (71.5 MB/s) - ‘P_RMSF.dat’ saved [15082/15082]
#
# --2025-02-28 22:43:57--  https://raw.githubusercontent.com/cpariona/biomedical-thesis/refs/heads/main/data/MD_results/3_Protein_UNPD_indolinone_42_100ns_310K_150mM-data/P_RMSF.dat
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 15082 (15K) [text/plain]
# Saving to: ‘P_RMSF.dat.1’
#
# P_RMSF.dat.1        100%[===================>]  14.73K  --.-KB/s    in 0s
#
# 2025-02-28 22:43:58 (89.3 MB/s) - ‘P_RMSF.dat.1’ saved [15082/15082]
#
# --2025-02-28 22:43:58--  https://raw.githubusercontent.com/cpariona/biomedical-thesis/refs/heads/main/data/MD_results/4_Protein_UNPD_indolinona_27_100ns_310K_150mM-data/P_RMSF.dat
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 15082 (15K) [text/plain]
# Saving to: ‘P_RMSF.dat.2’
#
# P_RMSF.dat.2        100%[===================>]  14.73K  --.-KB/s    in 0s
#
# 2025-02-28 22:43:58 (77.8 MB/s) - ‘P_RMSF.dat.2’ saved [15082/15082]

# %%
PL_RMSD_2 = pd.read_csv('PL_RMSD.dat', sep='\s+')
PL_RMSD_3 = pd.read_csv('PL_RMSD.dat.1', sep='\s+')
PL_RMSD_4 = pd.read_csv('PL_RMSD.dat.2', sep='\s+')

# %%
sns.set_style("white")
sns.set_style("ticks")
plt.figure(figsize=(8, 2), dpi=200)

sns.lineplot(data=PL_RMSD_2, x=PL_RMSD_2['#_frame#']/10, y='Prot_CA', label='UNPD82299', lw=0.7)
sns.lineplot(data=PL_RMSD_3, x=PL_RMSD_3['#_frame#']/10, y='Prot_CA', label='UNPD96223', lw=0.7)
sns.lineplot(data=PL_RMSD_4, x=PL_RMSD_4['#_frame#']/10, y='Prot_CA', label='UNPD228592', lw=0.7)

plt.title('(A) RMSD de la Proteina - Cα',fontweight='bold')
plt.xlabel('Tiempo (ns)', color='gray')
plt.ylabel('RMSD ($\it{Å}$)', color='gray')
plt.legend(loc="lower right")
#plt.savefig('rmsd_MeDFO.png', format='png', dpi=350)
plt.show()

# %%
sns.set_style("white")
sns.set_style("ticks")
plt.figure(figsize=(8, 4), dpi=200)

sns.lineplot(data=PL_RMSD_2, x=PL_RMSD_2['#_frame#']/10, y='Lig_wrt_Protein', label='UNPD82299', lw=0.7)
sns.lineplot(data=PL_RMSD_3, x=PL_RMSD_3['#_frame#']/10, y='Lig_wrt_Protein', label='UNPD96223', lw=0.7)
sns.lineplot(data=PL_RMSD_4, x=PL_RMSD_4['#_frame#']/10, y='Lig_wrt_Protein', label='UNPD228592', lw=0.7)

plt.title('RMSD del Ligando',fontweight='bold')
plt.xlabel('Tiempo (ns)', color='gray')
plt.ylabel('RMSD ($\it{Å}$)', color='gray')
plt.legend(loc="lower right")
#plt.savefig('rmsd_MeDFO.png', format='png', dpi=350)
plt.show()

# %%
L_Properties_2 = pd.read_csv('L-Properties.dat', sep='\s+')
L_Properties_3 = pd.read_csv('L-Properties.dat.1', sep='\s+')
L_Properties_4 = pd.read_csv('L-Properties.dat.2', sep='\s+')

# %%
sns.set_style("white")
sns.set_style("ticks")
plt.figure(figsize=(8, 2), dpi=200)

sns.lineplot(data=L_Properties_2, x=L_Properties_2['Frame_#']/10, y='SASA', label='UNPD82299', lw=0.7)
sns.lineplot(data=L_Properties_3, x=L_Properties_3['Frame_#']/10, y='SASA', label='UNPD96223', lw=0.7)
sns.lineplot(data=L_Properties_4, x=L_Properties_4['Frame_#']/10, y='SASA', label='UNPD228592', lw=0.7)

plt.title('(A) SASA del Ligando',fontweight='bold')
plt.xlabel('Tiempo (ns)', color='gray')
plt.ylabel('SASA ($\it{Å^2}$)', color='gray')
plt.legend(loc="lower right")
#plt.savefig('rmsd_MeDFO.png', format='png', dpi=350)
plt.show()

# %%
sns.set_style("white")
sns.set_style("ticks")
plt.figure(figsize=(8, 2), dpi=200)

sns.lineplot(data=L_Properties_2, x=L_Properties_2['Frame_#']/10, y='rGyr', label='UNPD82299', lw=0.7)
sns.lineplot(data=L_Properties_3, x=L_Properties_3['Frame_#']/10, y='rGyr', label='UNPD96223', lw=0.7)
sns.lineplot(data=L_Properties_4, x=L_Properties_4['Frame_#']/10, y='rGyr', label='UNPD228592', lw=0.7)

plt.title('(B) rGyr Ligando',fontweight='bold')
plt.xlabel('Tiempo (ns)', color='gray')
plt.ylabel('rGyr ($\it{Å}$)', color='gray')
plt.legend(loc="lower right")
#plt.savefig('rmsd_MeDFO.png', format='png', dpi=350)
plt.show()

# %%
P_RMSF_2 = pd.read_csv('P_RMSF.dat', sep='\s+')
P_RMSF_3 = pd.read_csv('P_RMSF.dat.1', sep='\s+')
P_RMSF_4 = pd.read_csv('P_RMSF.dat.2', sep='\s+')

# %%
sns.set_style("white")
sns.set_style("ticks")
plt.figure(figsize=(8, 2), dpi=200)

sns.lineplot(data=P_RMSF_2, x=P_RMSF_2['#_Residue#']+1, y='CA', label='UNPD82299', lw=0.7)
sns.lineplot(data=P_RMSF_3, x=P_RMSF_3['#_Residue#']+1, y='CA', label='UNPD96223', lw=0.7)
sns.lineplot(data=P_RMSF_4, x=P_RMSF_4['#_Residue#']+1, y='CA', label='UNPD228592', lw=0.7)

plt.title('(B) RMSF de la Proteina',fontweight='bold')
plt.xlabel('Residuo', color='gray')
plt.ylabel('RMSF ($\it{Å}$)', color='gray')
plt.legend(loc="lower right")
#plt.savefig('rmsd_MeDFO.png', format='png', dpi=350)
plt.show()

# %%
P_RMSF_2
# Out:
#      #_Residue# Chain  ResName LigandContact     CA  Backbone  Sidechain  \
# 0             0     _    MET_1           Yes  10.62       NaN        NaN
# 1             1     _    ASP_2            No  11.13       NaN        NaN
# 2             2     _    VAL_3            No  10.84       NaN        NaN
# 3             3     _    PHE_4           Yes  10.62       NaN        NaN
# 4             4     _    MET_5           Yes   9.30       NaN        NaN
# ..          ...   ...      ...           ...    ...       ...        ...
# 135         135     _  TYR_136            No  13.15       NaN        NaN
# 136         136     _  GLU_137            No  13.93       NaN        NaN
# 137         137     _  PRO_138            No  13.84       NaN        NaN
# 138         138     _  GLU_139            No  14.89       NaN        NaN
# 139         139     _  ALA_140            No  15.69       NaN        NaN
#
#      All_Heavy  B-factor
# 0          NaN       0.0
# 1          NaN       NaN
# 2          NaN       NaN
# 3          NaN       NaN
# 4          NaN       NaN
# ..         ...       ...
# 135        NaN       NaN
# 136        NaN       NaN
# 137        NaN       NaN
# 138        NaN       NaN
# 139        NaN       NaN
#
# [140 rows x 9 columns]

# %%
df = pd.DataFrame()

# %%
df['time(ns)'] = PL_RMSD_2['#_frame#']/10
df['RMSD_indolinone41'] = PL_RMSD_2['Prot_CA']
df['RMSD_indolinone42'] = PL_RMSD_3['Prot_CA']
df['RMSD_indolinone27'] = PL_RMSD_4['Prot_CA']
df['SASA_indolinone41'] = L_Properties_2['SASA']
df['SASA_indolinone42'] = L_Properties_3['SASA']
df['SASA_indolinone27'] = L_Properties_4['SASA']
df['rGyr_indolinone41'] = L_Properties_2['rGyr']
df['rGyr_indolinone42'] = L_Properties_3['rGyr']
df['rGyr_indolinone27'] = L_Properties_4['rGyr']

# %%
df.describe()
# Out:
#           time(ns)  RMSD_indolinone41  RMSD_indolinone42  RMSD_indolinone27  \
# count  1001.000000        1001.000000        1001.000000        1001.000000
# mean     50.000000          30.071716          26.637684          36.107560
# std      28.910811           4.078304           4.214422           4.890328
# min       0.000000           0.000000           0.000000           0.000000
# 25%      25.000000          29.946000          25.875000          35.816000
# 50%      50.000000          30.638000          26.791000          37.056000
# 75%      75.000000          31.700000          28.077000          38.258000
# max     100.000000          36.162000          33.733000          41.302000
#
#        SASA_indolinone41  SASA_indolinone42  SASA_indolinone27  \
# count        1001.000000        1001.000000        1001.000000
# mean          164.252698         142.896719         184.502800
# std            50.841227          60.442598          56.051586
# min            21.828000          58.858000          72.185000
# 25%           136.058000          96.424000         151.216000
# 50%           159.036000         124.225000         180.749000
# 75%           195.359000         170.067000         202.701000
# max           360.782000         345.625000         555.550000
#
#        rGyr_indolinone41  rGyr_indolinone42  rGyr_indolinone27
# count        1001.000000        1001.000000        1001.000000
# mean            3.461854           3.625542           4.004426
# std             0.029516           0.024247           0.033139
# min             3.352000           3.550000           3.853000
# 25%             3.443000           3.609000           3.982000
# 50%             3.463000           3.625000           4.005000
# 75%             3.482000           3.641000           4.028000
# max             3.538000           3.694000           4.116000

# %%
# df.to_csv('data.csv', index=False)

# %%
df2 = pd.DataFrame()

# %%
df2['ResName'] = P_RMSF_2['ResName']
df2['LigandContact_indolinone41'] = P_RMSF_2['LigandContact']
df2['LigandContact_indolinone42'] = P_RMSF_3['LigandContact']
df2['LigandContact_indolinone27'] = P_RMSF_4['LigandContact']
df2['RMSF_indolinone41'] = P_RMSF_2['CA']
df2['RMSF_indolinone42'] = P_RMSF_3['CA']
df2['RMSF_indolinone27'] = P_RMSF_4['CA']

# %%
df2
# Out:
#      ResName LigandContact_indolinone41 LigandContact_indolinone42  \
# 0      MET_1                        Yes                         No
# 1      ASP_2                         No                        Yes
# 2      VAL_3                         No                        Yes
# 3      PHE_4                        Yes                        Yes
# 4      MET_5                        Yes                         No
# ..       ...                        ...                        ...
# 135  TYR_136                         No                         No
# 136  GLU_137                         No                         No
# 137  PRO_138                         No                         No
# 138  GLU_139                         No                         No
# 139  ALA_140                         No                         No
#
#     LigandContact_indolinone27  RMSF_indolinone41  RMSF_indolinone42  \
# 0                           No              10.62               6.45
# 1                           No              11.13               6.44
# 2                           No              10.84               6.66
# 3                           No              10.62               5.70
# 4                           No               9.30               5.25
# ..                         ...                ...                ...
# 135                         No              13.15              14.23
# 136                         No              13.93              14.27
# 137                         No              13.84              14.64
# 138                         No              14.89              14.60
# 139                         No              15.69              15.52
#
#      RMSF_indolinone27
# 0                19.23
# 1                17.83
# 2                16.78
# 3                15.22
# 4                14.56
# ..                 ...
# 135              15.14
# 136              16.41
# 137              17.12
# 138              18.47
# 139              19.74
#
# [140 rows x 7 columns]

# %%
df2.describe()
# Out:
#        RMSF_indolinone41  RMSF_indolinone42  RMSF_indolinone27
# count         140.000000         140.000000         140.000000
# mean            7.825857           7.768500           9.143357
# std             2.128518           2.508885           3.415829
# min             4.930000           3.710000           4.370000
# 25%             6.280000           6.075000           6.605000
# 50%             7.220000           6.750000           8.390000
# 75%             8.912500           9.362500          10.570000
# max            15.690000          15.520000          19.740000

# %%
# df2.to_csv('rmsf.csv', index=False)
