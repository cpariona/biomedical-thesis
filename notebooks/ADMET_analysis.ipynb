# %%
# !pip install admet-ai
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.9/16.9 MB 45.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.4/166.4 kB 18.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.9/34.9 MB 12.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 6.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 11.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 64.0 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...

# %%
from google.colab import files
from urllib.request import urlretrieve

import pandas as pd

# %% [markdown]
# # **PubChem**

# %%
# !admet_predict \
    --data_path data.csv \
    --save_path preds.csv \
    --smiles_column smiles

# %% [markdown]
# # **DurgBank**

# %%
# !wget https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/pre_filtered/DrugBank_curcumin.csv
# !admet_predict \
    --data_path DrugBank_curcumin.csv \
    --save_path DrugBank_curcumin_ADMET.csv \
    --smiles_column smiles
# Out:
# --2024-05-11 20:54:57--  https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/pre_filtered/DrugBank_curcumin.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 196 [text/plain]
# Saving to: ‘DrugBank_curcumin.csv.1’
#
# DrugBank_curcumin.c 100%[===================>]     196  --.-KB/s    in 0s
#
# 2024-05-11 20:54:57 (8.49 MB/s) - ‘DrugBank_curcumin.csv.1’ saved [196/196]
#
# Traceback (most recent call last):
#   File "/usr/local/bin/admet_predict", line 8, in <module>
#     sys.exit(admet_predict_command_line())
#   File "/usr/local/lib/python3.10/dist-packages/admet_ai/admet_predict.py", line 71, in admet_predict_command_line
#     tapify(admet_predict)
# ...

# %%
# !admet_predict \
    --data_path https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/pre_filtered/DrugBank_indolinone.csv \
    --save_path DrugBank_indolinone_ADMET.csv \
    --smiles_column smiles

# %%
# !admet_predict \
    --data_path https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/pre_filtered/DrugBank_stilbene.csv \
    --save_path DrugBank_stilbene_ADMET.csv \
    --smiles_column smiles
