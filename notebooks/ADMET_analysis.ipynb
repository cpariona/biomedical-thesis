# %%
# !pip install admet-ai
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.9/16.9 MB 27.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.4/166.4 kB 7.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.9/34.9 MB 10.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 3.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 8.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 43.4 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...

# %%
import pandas as pd

# %% [markdown]
# # **PubChem**

# %%
# !wget https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/pre_filtered/PubChem_curcumin.csv
# !admet_predict \
    --data_path PubChem_curcumin.csv \
    --save_path PubChem_curcumin_ADMET.csv \
    --smiles_column smiles
# Out:
# --2024-05-11 21:26:14--  https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/pre_filtered/PubChem_curcumin.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 182 [text/plain]
# Saving to: ‘PubChem_curcumin.csv’
#
# PubChem_curcumin.cs 100%[===================>]     182  --.-KB/s    in 0s
#
# 2024-05-11 21:26:14 (3.09 MB/s) - ‘PubChem_curcumin.csv’ saved [182/182]
#
# Loading pretrained parameter "encoder.encoder.0.cached_zero_vector".
# Loading pretrained parameter "encoder.encoder.0.W_i.weight".
# Loading pretrained parameter "encoder.encoder.0.W_h.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.bias".
# ...

# %%
# !wget https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/pre_filtered/PubChem_flavanol.csv
# !admet_predict \
    --data_path PubChem_flavanol.csv \
    --save_path PubChem_flavanol_ADMET.csv \
    --smiles_column smiles
# Out:
# --2024-05-11 21:26:36--  https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/pre_filtered/PubChem_flavanol.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 52121 (51K) [text/plain]
# Saving to: ‘PubChem_flavanol.csv’
#
# PubChem_flavanol.cs 100%[===================>]  50.90K  --.-KB/s    in 0.006s
#
# 2024-05-11 21:26:36 (8.30 MB/s) - ‘PubChem_flavanol.csv’ saved [52121/52121]
#
# Loading pretrained parameter "encoder.encoder.0.cached_zero_vector".
# Loading pretrained parameter "encoder.encoder.0.W_i.weight".
# Loading pretrained parameter "encoder.encoder.0.W_h.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.bias".
# ...

# %%
# !wget https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/pre_filtered/PubChem_indolinone.csv
# !admet_predict \
    --data_path PubChem_indolinone.csv \
    --save_path PubChem_indolinone_ADMET.csv \
    --smiles_column smiles

# %%
# !wget https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/pre_filtered/PubChem_stilbene.csv
# !admet_predict \
    --data_path PubChem_stilbene.csv \
    --save_path PubChem_stilbene_ADMET.csv \
    --smiles_column smiles

# %%
# !wget https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/pre_filtered/PubChem_sulfonamide.csv
# !admet_predict \
    --data_path PubChem_sulfonamide.csv \
    --save_path PubChem_sulfonamide_ADMET.csv \
    --smiles_column smiles

# %% [markdown]
# # **DurgBank**

# %%
# !wget https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/pre_filtered/DrugBank_curcumin.csv
# !admet_predict \
    --data_path DrugBank_curcumin.csv \
    --save_path DrugBank_curcimin_ADMET.csv \
    --smiles_column smiles

# %%
# !wget https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/pre_filtered/DrugBank_indolinone.csv
# !admet_predict \
    --data_path DrugBank_indolinone.csv \
    --save_path DrugBank_indolinone_ADMET.csv \
    --smiles_column smiles
# Out:
# --2024-05-11 21:08:43--  https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/pre_filtered/DrugBank_indolinone.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3636 (3.6K) [text/plain]
# Saving to: ‘DrugBank_indolinone.csv’
#
# DrugBank_indolinone 100%[===================>]   3.55K  --.-KB/s    in 0s
#
# 2024-05-11 21:08:43 (42.1 MB/s) - ‘DrugBank_indolinone.csv’ saved [3636/3636]
#
# Loading pretrained parameter "encoder.encoder.0.cached_zero_vector".
# Loading pretrained parameter "encoder.encoder.0.W_i.weight".
# Loading pretrained parameter "encoder.encoder.0.W_h.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.bias".
# ...

# %%
# !wget https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/pre_filtered/DrugBank_stilbene.csv
# !admet_predict \
    --data_path DrugBank_stilbene.csv \
    --save_path DrugBank_stilbene_ADMET.csv \
    --smiles_column smiles
# Out:
# --2024-05-11 21:09:03--  https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/pre_filtered/DrugBank_stilbene.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3618 (3.5K) [text/plain]
# Saving to: ‘DrugBank_stilbene.csv’
#
# DrugBank_stilbene.c 100%[===================>]   3.53K  --.-KB/s    in 0s
#
# 2024-05-11 21:09:03 (45.1 MB/s) - ‘DrugBank_stilbene.csv’ saved [3618/3618]
#
# Loading pretrained parameter "encoder.encoder.0.cached_zero_vector".
# Loading pretrained parameter "encoder.encoder.0.W_i.weight".
# Loading pretrained parameter "encoder.encoder.0.W_h.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.bias".
# ...

# %% [markdown]
# # **PeruNPDB**

# %%
# !wget https://github.com/cpariona/biomedical-thesis/blob/main/data/pre_filtered/PeruNPDB_indolinone.csv
# !admet_predict \
    --data_path PeruNPDB_indolinone.csv \
    --save_path PeruNPDB_indolinone_ADMET.csv \
    --smiles_column smiles
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/admet_predict", line 8, in <module>
#     sys.exit(admet_predict_command_line())
#   File "/usr/local/lib/python3.10/dist-packages/admet_ai/admet_predict.py", line 71, in admet_predict_command_line
#     tapify(admet_predict)
#   File "/usr/local/lib/python3.10/dist-packages/tap/tapify.py", line 335, in tapify
#     return class_or_function(**command_line_args_dict)
#   File "/usr/local/lib/python3.10/dist-packages/admet_ai/admet_predict.py", line 43, in admet_predict
#     data = load_and_preprocess_data(data_path=data_path, smiles_column=smiles_column)
#   File "/usr/local/lib/python3.10/dist-packages/admet_ai/utils.py", line 17, in load_and_preprocess_data
#     data = pd.read_csv(data_path)
#   File "/usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py", line 912, in read_csv
#     return _read(filepath_or_buffer, kwds)
# ...

# %% [markdown]
# # **UNPD**

# %%
# !wget https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/pre_filtered/UNPD_curcumin.csv
# !admet_predict \
    --data_path UNPD_curcumin.csv \
    --save_path UNPD_curcumin_ADMET.csv \
    --smiles_column smiles
# Out:
# --2024-05-11 21:14:47--  https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/pre_filtered/UNPD_curcumin.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 751 [text/plain]
# Saving to: ‘UNPD_curcumin.csv’
#
# UNPD_curcumin.csv   100%[===================>]     751  --.-KB/s    in 0s
#
# 2024-05-11 21:14:47 (24.3 MB/s) - ‘UNPD_curcumin.csv’ saved [751/751]
#
# Loading pretrained parameter "encoder.encoder.0.cached_zero_vector".
# Loading pretrained parameter "encoder.encoder.0.W_i.weight".
# Loading pretrained parameter "encoder.encoder.0.W_h.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.bias".
# Loading pretrained parameter "readout.1.weight".
# ...

# %%
# !wget https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/pre_filtered/UNPD_flavanol.csv
# !admet_predict \
    --data_path UNPD_flavanol.csv \
    --save_path UNPD_flavanol_ADMET.csv \
    --smiles_column smiles
# Out:
# --2024-05-11 21:15:38--  https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/pre_filtered/UNPD_flavanol.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 27085 (26K) [text/plain]
# Saving to: ‘UNPD_flavanol.csv’
#
# UNPD_flavanol.csv   100%[===================>]  26.45K  --.-KB/s    in 0s
#
# 2024-05-11 21:15:38 (102 MB/s) - ‘UNPD_flavanol.csv’ saved [27085/27085]
#
# Loading pretrained parameter "encoder.encoder.0.cached_zero_vector".
# Loading pretrained parameter "encoder.encoder.0.W_i.weight".
# Loading pretrained parameter "encoder.encoder.0.W_h.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.bias".
# ...

# %%
# !wget https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/pre_filtered/UNPD_indolinone.csv
# !admet_predict \
    --data_path UNPD_indolinone.csv \
    --save_path UNPD_indolinone_ADMET.csv \
    --smiles_column smiles
# Out:
# --2024-05-11 21:17:00--  https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/pre_filtered/UNPD_indolinone.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 29848 (29K) [text/plain]
# Saving to: ‘UNPD_indolinone.csv’
#
# UNPD_indolinone.csv 100%[===================>]  29.15K  --.-KB/s    in 0s
#
# 2024-05-11 21:17:00 (76.6 MB/s) - ‘UNPD_indolinone.csv’ saved [29848/29848]
#
# Loading pretrained parameter "encoder.encoder.0.cached_zero_vector".
# Loading pretrained parameter "encoder.encoder.0.W_i.weight".
# Loading pretrained parameter "encoder.encoder.0.W_h.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.bias".
# ...

# %%
# !wget https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/pre_filtered/UNPD_stilbene.csv
# !admet_predict \
    --data_path UNPD_stilbene.csv \
    --save_path UNPD_stilbene_ADMET.csv \
    --smiles_column smiles
# Out:
# --2024-05-11 21:18:36--  https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/pre_filtered/UNPD_stilbene.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 66276 (65K) [text/plain]
# Saving to: ‘UNPD_stilbene.csv’
#
# UNPD_stilbene.csv   100%[===================>]  64.72K  --.-KB/s    in 0.002s
#
# 2024-05-11 21:18:36 (34.8 MB/s) - ‘UNPD_stilbene.csv’ saved [66276/66276]
#
# Loading pretrained parameter "encoder.encoder.0.cached_zero_vector".
# Loading pretrained parameter "encoder.encoder.0.W_i.weight".
# Loading pretrained parameter "encoder.encoder.0.W_h.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.bias".
# ...

# %% [markdown]
# # **NuBBE**

# %%
# !wget https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/pre_filtered/NuBBE_indolinone.csv
# !admet_predict \
    --data_path NuBBE_indolinone.csv \
    --save_path NuBBE_indolinone_ADMET.csv \
    --smiles_column smiles
# Out:
# --2024-05-11 21:21:42--  https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/pre_filtered/NuBBE_indolinone.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 282 [text/plain]
# Saving to: ‘NuBBE_indolinone.csv’
#
# NuBBE_indolinone.cs 100%[===================>]     282  --.-KB/s    in 0s
#
# 2024-05-11 21:21:42 (11.1 MB/s) - ‘NuBBE_indolinone.csv’ saved [282/282]
#
# Loading pretrained parameter "encoder.encoder.0.cached_zero_vector".
# Loading pretrained parameter "encoder.encoder.0.W_i.weight".
# Loading pretrained parameter "encoder.encoder.0.W_h.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.bias".
# ...

# %%
# !wget https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/pre_filtered/NuBBE_stilbene.csv
# !admet_predict \
    --data_path NuBBE_stilbene.csv \
    --save_path NuBBE_stilbene_ADMET.csv \
    --smiles_column smiles
# Out:
# --2024-05-11 21:22:07--  https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/pre_filtered/NuBBE_stilbene.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 423 [text/plain]
# Saving to: ‘NuBBE_stilbene.csv’
#
# NuBBE_stilbene.csv  100%[===================>]     423  --.-KB/s    in 0s
#
# 2024-05-11 21:22:07 (6.48 MB/s) - ‘NuBBE_stilbene.csv’ saved [423/423]
#
# Loading pretrained parameter "encoder.encoder.0.cached_zero_vector".
# Loading pretrained parameter "encoder.encoder.0.W_i.weight".
# Loading pretrained parameter "encoder.encoder.0.W_h.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.bias".
# Loading pretrained parameter "readout.1.weight".
# ...
