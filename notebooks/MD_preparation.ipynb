# %% [markdown]
# # **Prepare the protein and ligands topology**
#
# Preparing the ligand and protein topology is a crucial step in molecular simulations, such as molecular dynamics (MD) simulations.
#
# Protein topology preparation involves defining the molecular structure of the protein, including its atomic coordinates, bond connectivity, angles, dihedrals, and other parameters required for simulations. Ligand topology preparation involves similar steps for small molecules (ligands) that might bind to the protein.

# %%
# %%capture
# !apt install gromacs

# %%capture
# !pip install py3dmol

# %%
# See the installed GROMACS version
# !gmx pdb2gmx --version
# Out:
#              :-) GROMACS - gmx pdb2gmx, 2021.4-Ubuntu-2021.4-2 (-:
#
#                             GROMACS is written by:
#      Andrey Alekseenko              Emile Apol              Rossen Apostolov
#          Paul Bauer           Herman J.C. Berendsen           Par Bjelkmar
#        Christian Blau           Viacheslav Bolnykh             Kevin Boyd
#      Aldert van Buuren           Rudi van Drunen             Anton Feenstra
#     Gilles Gouaillardet             Alan Gray               Gerrit Groenhof
#        Anca Hamuraru            Vincent Hindriksen          M. Eric Irrgang
#       Aleksei Iupinov           Christoph Junghans             Joe Jordan
#     Dimitrios Karkoulis            Peter Kasson                Jiri Kraus
#       Carsten Kutzner              Per Larsson              Justin A. Lemkul
#        Viveca Lindahl            Magnus Lundborg             Erik Marklund
#         Pascal Merz             Pieter Meulenhoff            Teemu Murtola
#         Szilard Pall               Sander Pronk              Roland Schulz
#        Michael Shirts            Alexey Shvetsov             Alfons Sijbers
#        Peter Tieleman              Jon Vincent              Teemu Virolainen
#      Christian Wennberg            Maarten Wolf              Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx pdb2gmx, version 2021.4-Ubuntu-2021.4-2
# Executable:   /usr/bin/gmx
# Data prefix:  /usr
# Working dir:  /content
# Command line:
#   gmx pdb2gmx --version
#
# GROMACS version:    2021.4-Ubuntu-2021.4-2
# Precision:          mixed
# Memory model:       64 bit
# MPI library:        thread_mpi
# OpenMP support:     enabled (GMX_OPENMP_MAX_THREADS = 64)
# GPU support:        disabled
# SIMD instructions:  SSE4.1
# FFT library:        fftw-3.3.8-sse2-avx
# RDTSCP usage:       enabled
# TNG support:        enabled
# Hwloc support:      hwloc-2.5.0
# Tracing support:    disabled
# C compiler:         /usr/bin/cc GNU 11.2.0
# C compiler flags:   -msse4.1 -Wno-missing-field-initializers -fexcess-precision=fast -funroll-all-loops -O3 -DNDEBUG
# C++ compiler:       /usr/bin/c++ GNU 11.2.0
# C++ compiler flags: -msse4.1 -Wno-missing-field-initializers -fexcess-precision=fast -funroll-all-loops -fopenmp -O3 -DNDEBUG

# %% [markdown]
# ## **Prepare the Protein Topology**
#
# 1.   Prepare the protein topology using the CHARMM36 force field (download the latest available force field and the conversion script "cgenff_charmm2gmx.py" from the MacKerell lab website).
# 2.   Decompress the force field tarball
# 3.   Use the "charmm36-jul2022.ff" directory to write the topology (select the CHARMM36 force field, the CHARMM-modified TIP3P water model, and the terminal types "NH3+" and "COO-").

# %%
# Download the latest CHARMM36 force field and protein
# CORREGIR NO SE DEBE DESCARGAR ASI
# !wget https://github.com/cpariona/biomedical-thesis/blob/main/data/MD_preparation/charmm36-jul2022.ff.tgz # get force field
# !wget https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/MD_preparation/1xq8.pdb # get protein
# Out:
# --2024-08-05 09:09:28--  https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/MD_preparation/1xq8.pdb
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 163378 (160K) [text/plain]
# Saving to: ‘1xq8.pdb’
#
# 1xq8.pdb            100%[===================>] 159.55K  --.-KB/s    in 0.03s
#
# 2024-08-05 09:09:29 (6.18 MB/s) - ‘1xq8.pdb’ saved [163378/163378]

# %%
# Unarchive the force field tarball
# !tar -zxvf charmm36-jul2022.ff.tgz
# Out:
# charmm36-jul2022.ff/
# charmm36-jul2022.ff/solvent.n.tdb
# charmm36-jul2022.ff/ethers.hdb
# charmm36-jul2022.ff/tip5p.itp
# charmm36-jul2022.ff/cgenff.rtp
# charmm36-jul2022.ff/spc.itp
# charmm36-jul2022.ff/lipid.n.tdb
# charmm36-jul2022.ff/solvent.rtp
# charmm36-jul2022.ff/na.c.tdb
# charmm36-jul2022.ff/ethers.rtp
# charmm36-jul2022.ff/metals.hdb
# charmm36-jul2022.ff/solvent.c.tdb
# charmm36-jul2022.ff/aminoacids.r2b
# charmm36-jul2022.ff/lipid.rtp
# charmm36-jul2022.ff/cgenff.n.tdb
# charmm36-jul2022.ff/tip3p_original.itp
# charmm36-jul2022.ff/silicates.c.tdb
# charmm36-jul2022.ff/ffnonbonded.itp
# charmm36-jul2022.ff/na.hdb
# charmm36-jul2022.ff/lipid.c.tdb
# charmm36-jul2022.ff/cmap.itp
# charmm36-jul2022.ff/ethers.n.tdb
# charmm36-jul2022.ff/spce.itp
# charmm36-jul2022.ff/tip3p.itp
# charmm36-jul2022.ff/aminoacids.arn
# charmm36-jul2022.ff/cgenff.c.tdb
# charmm36-jul2022.ff/silicates.r2b
# charmm36-jul2022.ff/atomtypes.atp
# charmm36-jul2022.ff/carb.r2b
# charmm36-jul2022.ff/watermodels.dat
# charmm36-jul2022.ff/aminoacids.rtp
# charmm36-jul2022.ff/tip4pew.itp
# charmm36-jul2022.ff/aminoacids.c.tdb
# charmm36-jul2022.ff/solvent.hdb
# charmm36-jul2022.ff/silicates.n.tdb
# charmm36-jul2022.ff/aminoacids.hdb
# charmm36-jul2022.ff/nbfix.itp
# charmm36-jul2022.ff/metals.rtp
# charmm36-jul2022.ff/silicates.rtp
# charmm36-jul2022.ff/na.n.tdb
# charmm36-jul2022.ff/metals.c.tdb
# charmm36-jul2022.ff/ffbonded.itp
# charmm36-jul2022.ff/ions.itp
# charmm36-jul2022.ff/forcefield.itp
# charmm36-jul2022.ff/forcefield.doc
# charmm36-jul2022.ff/carb.hdb
# charmm36-jul2022.ff/ethers.r2b
# charmm36-jul2022.ff/solvent.r2b
# charmm36-jul2022.ff/metals.r2b
# charmm36-jul2022.ff/carb.rtp
# charmm36-jul2022.ff/lipid.hdb
# charmm36-jul2022.ff/carb.c.tdb
# charmm36-jul2022.ff/aminoacids.n.tdb
# charmm36-jul2022.ff/carb.n.tdb
# charmm36-jul2022.ff/lipid.r2b
# charmm36-jul2022.ff/ffmissingdihedrals.itp
# charmm36-jul2022.ff/ethers.c.tdb
# charmm36-jul2022.ff/na.rtp
# charmm36-jul2022.ff/tip4p.itp
# charmm36-jul2022.ff/metals.n.tdb
# charmm36-jul2022.ff/na.r2b
# charmm36-jul2022.ff/cgenff.r2b
# charmm36-jul2022.ff/cgenff.hdb
# charmm36-jul2022.ff/silicates.hdb

# %%
# Write the topology with pdb2gmx
# !gmx pdb2gmx -f 1xq8.pdb -o 1xq8_processed.gro -ignh -ter
# Select the CHARMM36 force field
# Select the CHARMM-modified TIP3P water model
# Select the terminal type "NH3+" and "COO-"
# Out:
#              :-) GROMACS - gmx pdb2gmx, 2021.4-Ubuntu-2021.4-2 (-:
#
#                             GROMACS is written by:
#      Andrey Alekseenko              Emile Apol              Rossen Apostolov
#          Paul Bauer           Herman J.C. Berendsen           Par Bjelkmar
#        Christian Blau           Viacheslav Bolnykh             Kevin Boyd
#      Aldert van Buuren           Rudi van Drunen             Anton Feenstra
#     Gilles Gouaillardet             Alan Gray               Gerrit Groenhof
#        Anca Hamuraru            Vincent Hindriksen          M. Eric Irrgang
#       Aleksei Iupinov           Christoph Junghans             Joe Jordan
#     Dimitrios Karkoulis            Peter Kasson                Jiri Kraus
#       Carsten Kutzner              Per Larsson              Justin A. Lemkul
#        Viveca Lindahl            Magnus Lundborg             Erik Marklund
#         Pascal Merz             Pieter Meulenhoff            Teemu Murtola
#         Szilard Pall               Sander Pronk              Roland Schulz
#        Michael Shirts            Alexey Shvetsov             Alfons Sijbers
#        Peter Tieleman              Jon Vincent              Teemu Virolainen
#      Christian Wennberg            Maarten Wolf              Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx pdb2gmx, version 2021.4-Ubuntu-2021.4-2
# Executable:   /usr/bin/gmx
# Data prefix:  /usr
# Working dir:  /content
# Command line:
#   gmx pdb2gmx -f 1xq8.pdb -o 1xq8_processed.gro -ignh -ter
#
# Select the Force Field:
#
# From current directory:
#
#  1: CHARMM all-atom force field
#
# From '/usr/share/gromacs/top':
#
#  2: AMBER03 protein, nucleic AMBER94 (Duan et al., J. Comp. Chem. 24, 1999-2012, 2003)
#
#  3: AMBER94 force field (Cornell et al., JACS 117, 5179-5197, 1995)
#
#  4: AMBER96 protein, nucleic AMBER94 (Kollman et al., Acc. Chem. Res. 29, 461-469, 1996)
#
#  5: AMBER99 protein, nucleic AMBER94 (Wang et al., J. Comp. Chem. 21, 1049-1074, 2000)
#
#  6: AMBER99SB protein, nucleic AMBER94 (Hornak et al., Proteins 65, 712-725, 2006)
#
#  7: AMBER99SB-ILDN protein, nucleic AMBER94 (Lindorff-Larsen et al., Proteins 78, 1950-58, 2010)
#
#  8: AMBERGS force field (Garcia & Sanbonmatsu, PNAS 99, 2782-2787, 2002)
#
#  9: CHARMM27 all-atom force field (CHARM22 plus CMAP for proteins)
#
# 10: GROMOS96 43a1 force field
#
# 11: GROMOS96 43a2 force field (improved alkane dihedrals)
#
# 12: GROMOS96 45a3 force field (Schuler JCC 2001 22 1205)
#
# 13: GROMOS96 53a5 force field (JCC 2004 vol 25 pag 1656)
#
# 14: GROMOS96 53a6 force field (JCC 2004 vol 25 pag 1656)
#
# 15: GROMOS96 54a7 force field (Eur. Biophys. J. (2011), 40,, 843-856, DOI: 10.1007/s00249-011-0700-9)
#
# 16: OPLS-AA/L all-atom force field (2001 aminoacid dihedrals)
# 1
#
# Using the Charmm36-jul2022 force field in directory ./charmm36-jul2022.ff
# Opening force field file ./charmm36-jul2022.ff/watermodels.dat
#
# Select the Water Model:
#
#  1: TIP3P      CHARMM-modified TIP3P water model (recommended over original TIP3P)
#
#  2: TIP3P_ORIGINAL Original TIP3P water model
#
#  3: SPC        SPC water model
#
#  4: SPCE       SPC/E water model
#
#  5: TIP5P      TIP5P water model
#
#  6: TIP4P      TIP4P water model
#
#  7: TIP4PEW    TIP4P/Ew water model
#
#  8: None
# 1
#
# going to rename ./charmm36-jul2022.ff/aminoacids.r2b
# Opening force field file ./charmm36-jul2022.ff/aminoacids.r2b
#
# going to rename ./charmm36-jul2022.ff/carb.r2b
# Opening force field file ./charmm36-jul2022.ff/carb.r2b
#
# going to rename ./charmm36-jul2022.ff/cgenff.r2b
# Opening force field file ./charmm36-jul2022.ff/cgenff.r2b
#
# going to rename ./charmm36-jul2022.ff/ethers.r2b
# Opening force field file ./charmm36-jul2022.ff/ethers.r2b
#
# going to rename ./charmm36-jul2022.ff/lipid.r2b
# Opening force field file ./charmm36-jul2022.ff/lipid.r2b
#
# going to rename ./charmm36-jul2022.ff/metals.r2b
# Opening force field file ./charmm36-jul2022.ff/metals.r2b
#
# going to rename ./charmm36-jul2022.ff/na.r2b
# Opening force field file ./charmm36-jul2022.ff/na.r2b
#
# going to rename ./charmm36-jul2022.ff/silicates.r2b
# Opening force field file ./charmm36-jul2022.ff/silicates.r2b
#
# going to rename ./charmm36-jul2022.ff/solvent.r2b
# Opening force field file ./charmm36-jul2022.ff/solvent.r2b
# Reading 1xq8.pdb...
# Read '', 1013 atoms
#
# Analyzing pdb file
# Splitting chemical chains based on TER records or chain id changing.
#
# There are 1 chains and 0 blocks of water and 140 residues with 1013 atoms
#
#   chain  #res #atoms
#
#   1 ' '   140   1013
#
# All occupancy fields zero. This is probably not an X-Ray structure
# All occupancy fields zero. This is probably not an X-Ray structure
# Opening force field file ./charmm36-jul2022.ff/atomtypes.atp
#
# Reading residue database... (Charmm36-jul2022)
# Opening force field file ./charmm36-jul2022.ff/aminoacids.rtp
# Opening force field file ./charmm36-jul2022.ff/carb.rtp
# Opening force field file ./charmm36-jul2022.ff/cgenff.rtp
# Opening force field file ./charmm36-jul2022.ff/ethers.rtp
# Opening force field file ./charmm36-jul2022.ff/lipid.rtp
# Opening force field file ./charmm36-jul2022.ff/metals.rtp
# Opening force field file ./charmm36-jul2022.ff/na.rtp
# Opening force field file ./charmm36-jul2022.ff/silicates.rtp
# Opening force field file ./charmm36-jul2022.ff/solvent.rtp
# Opening force field file ./charmm36-jul2022.ff/aminoacids.hdb
# Opening force field file ./charmm36-jul2022.ff/carb.hdb
# Opening force field file ./charmm36-jul2022.ff/cgenff.hdb
# Opening force field file ./charmm36-jul2022.ff/ethers.hdb
# Opening force field file ./charmm36-jul2022.ff/lipid.hdb
# Opening force field file ./charmm36-jul2022.ff/metals.hdb
# Opening force field file ./charmm36-jul2022.ff/na.hdb
# Opening force field file ./charmm36-jul2022.ff/silicates.hdb
# Opening force field file ./charmm36-jul2022.ff/solvent.hdb
# Opening force field file ./charmm36-jul2022.ff/aminoacids.n.tdb
# Opening force field file ./charmm36-jul2022.ff/carb.n.tdb
# Opening force field file ./charmm36-jul2022.ff/cgenff.n.tdb
# Opening force field file ./charmm36-jul2022.ff/ethers.n.tdb
# Opening force field file ./charmm36-jul2022.ff/lipid.n.tdb
# Opening force field file ./charmm36-jul2022.ff/metals.n.tdb
# Opening force field file ./charmm36-jul2022.ff/na.n.tdb
# Opening force field file ./charmm36-jul2022.ff/silicates.n.tdb
# Opening force field file ./charmm36-jul2022.ff/solvent.n.tdb
# Opening force field file ./charmm36-jul2022.ff/aminoacids.c.tdb
# Opening force field file ./charmm36-jul2022.ff/carb.c.tdb
# Opening force field file ./charmm36-jul2022.ff/cgenff.c.tdb
# Opening force field file ./charmm36-jul2022.ff/ethers.c.tdb
# Opening force field file ./charmm36-jul2022.ff/lipid.c.tdb
# Opening force field file ./charmm36-jul2022.ff/metals.c.tdb
# Opening force field file ./charmm36-jul2022.ff/na.c.tdb
# Opening force field file ./charmm36-jul2022.ff/silicates.c.tdb
# Opening force field file ./charmm36-jul2022.ff/solvent.c.tdb
#
# Processing chain 1 (1013 atoms, 140 residues)
# Analysing hydrogen-bonding network for automated assignment of histidine
#  protonation. 184 donors and 215 acceptors were found.
# There are 217 hydrogen bonds
# Will use HISE for residue 50
#
# Identified residue MET1 as a starting terminus.
#
# Identified residue ALA140 as a ending terminus.
# 8 out of 8 lines of specbond.dat converted successfully
# Special Atom Distance matrix:
#                     MET1    MET5   HIS50  MET116
#                      SD7    SD41  NE2360   SD817
#     MET5    SD41   1.179
#    HIS50  NE2360   5.996   5.363
#   MET116   SD817   7.094   7.313  10.848
#   MET127   SD905   8.435   8.809  12.743   2.072
# Select start terminus type for MET-1
#  0: MET1
#  1: NH3+
#  2: NH2
#  3: HYD1
#  4: 5TER
#  5: 5MET
#  6: 5PHO
#  7: 5POM
#  8: None
# 1
# Start terminus MET-1: NH3+
# Select end terminus type for ALA-140
#  0: COO-
#  1: COOH
#  2: CT2
#  3: CT1
#  4: HYD2
#  5: MET2
#  6: 3TER
#  7: None
# 0
# End terminus ALA-140: COO-
# Opening force field file ./charmm36-jul2022.ff/aminoacids.arn
#
# Checking for duplicate atoms....
#
# Generating any missing hydrogen atoms and/or adding termini.
#
# Now there are 140 residues with 2016 atoms
#
# Making bonds...
#
# Number of bonds was 2027, now 2027
#
# Generating angles, dihedrals and pairs...
# Before cleaning: 5323 pairs
# Before cleaning: 5353 dihedrals
# Keeping all generated dihedrals
#
# Making cmap torsions...
#
# There are  138 cmap torsion pairs
#
# There are 5353 dihedrals,  345 impropers, 3692 angles
#           5305 pairs,     2027 bonds and     0 virtual sites
#
# Total mass 14451.193 a.m.u.
#
# Total charge -9.000 e
#
# Writing topology
#
# Writing coordinate file...
#
# 		--------- PLEASE NOTE ------------
#
# You have successfully generated a topology from: 1xq8.pdb.
#
# The Charmm36-jul2022 force field and the tip3p water model are used.
#
# 		--------- ETON ESAELP ------------
#
# GROMACS reminds you: "If You Want Something Done You Have to Do It Yourself" (Highlander II)

# %% [markdown]
# ## **Prepare the Ligand Topology**

# %% [markdown]
# 1.   Create a .mol2 file with the ligand and add the missing hydrogens. Open ligand.pdb in Avogadro, and from the "Build" menu, choose "Add Hydrogens." Avogadro will build all of the hydrogen atoms onto the ligand. Save a .mol2 file (File -> Save As... and choose Sybyl Mol2 from the drop-down menu) named "ligand.mol2."
# 2.   Open the .mol2 file to make some changes:
#   *   Replace "*****" with "LigandName,"
#   *   Fix the residue names and numbers so that they are all the same
#   *   Download sort_mol2_bonds.pl [http://www.mdtutorials.com/gmx/complex/Files/sort_mol2_bonds.pl] and run it with perl using the command: `perl sort_mol2_bonds.pl ligand.mol2 ligand_fix.mol2`
# 3.   Generate the topology: Visit the CGenFF server, log into your account, and click "Upload molecule" at the top of the page. Upload the .mol2 file, and the CGenFF server will quickly return a topology in the form of a CHARMM "stream" file (extension .str).
# 4.   Download the script cgenff_charmm2gmx.py from this GitHub site [https://github.com/Lemkul-Lab/cgenff_charmm2gmx] and run `python cgenff_charmm2gmx.py JZ4 jz4_fix.mol2 jz4.str charmm36-jul2022.ff`.

# %%
# First do steps 1 and 2.1-2 manually
# Download sort_mol2_bonds.pl
# !wget https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/MD_preparation/sort_mol2_bonds.pl
# Out:
# --2024-08-05 09:45:27--  https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/MD_preparation/sort_mol2_bonds.pl
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3490 (3.4K) [text/plain]
# Saving to: ‘sort_mol2_bonds.pl’
#
# sort_mol2_bonds.pl  100%[===================>]   3.41K  --.-KB/s    in 0s
#
# 2024-08-05 09:45:27 (41.3 MB/s) - ‘sort_mol2_bonds.pl’ saved [3490/3490]

# %%
# Donwload ligands fixed
# !wget https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/MD_preparation/ligands_top/1_lig_opt_DrugBank_stilbene_8.mol2
# !wget https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/MD_preparation/ligands_top/2_lig_opt_PubChem_flavanol_399.mol2
# !wget https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/MD_preparation/ligands_top/3_lig_opt_PubChem_flavanol_451.mol2
# !wget https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/MD_preparation/ligands_top/4_lig_opt_UNPD_indolinone_27.mol2
# !wget https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/MD_preparation/ligands_top/5_lig_opt_UNPD_indolinone_41.mol2
# !wget https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/MD_preparation/ligands_top/6_lig_opt_UNPD_indolinone_42.mol2
# !wget https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/MD_preparation/ligands_control/1_lig_opt_control_1.mol2
# !wget https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/MD_preparation/ligands_control/2_lig_opt_control_2.mol2
# !wget https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/MD_preparation/ligands_control/3_lig_opt_control_3.mol2
# !wget https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/MD_preparation/ligands_control/4_lig_opt_control_4.mol2
# Out:
# --2024-08-05 09:10:52--  https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/MD_preparation/ligands_top/1_lig_opt_DrugBank_stilbene_8.mol2
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5040 (4.9K) [text/plain]
# Saving to: ‘1_lig_opt_DrugBank_stilbene_8.mol2’
#
# 1_lig_opt_DrugBank_ 100%[===================>]   4.92K  --.-KB/s    in 0s
#
# 2024-08-05 09:10:52 (54.3 MB/s) - ‘1_lig_opt_DrugBank_stilbene_8.mol2’ saved [5040/5040]
#
# --2024-08-05 09:10:52--  https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/MD_preparation/ligands_top/2_lig_opt_PubChem_flavanol_399.mol2
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3603 (3.5K) [text/plain]
# Saving to: ‘2_lig_opt_PubChem_flavanol_399.mol2’
#
# 2_lig_opt_PubChem_f 100%[===================>]   3.52K  --.-KB/s    in 0s
#
# 2024-08-05 09:10:53 (53.9 MB/s) - ‘2_lig_opt_PubChem_flavanol_399.mol2’ saved [3603/3603]
#
# --2024-08-05 09:10:53--  https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/MD_preparation/ligands_top/3_lig_opt_PubChem_flavanol_451.mol2
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4488 (4.4K) [text/plain]
# Saving to: ‘3_lig_opt_PubChem_flavanol_451.mol2’
#
# 3_lig_opt_PubChem_f 100%[===================>]   4.38K  --.-KB/s    in 0s
#
# 2024-08-05 09:10:53 (45.1 MB/s) - ‘3_lig_opt_PubChem_flavanol_451.mol2’ saved [4488/4488]
#
# --2024-08-05 09:10:53--  https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/MD_preparation/ligands_top/4_lig_opt_UNPD_indolinone_27.mol2
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4130 (4.0K) [text/plain]
# Saving to: ‘4_lig_opt_UNPD_indolinone_27.mol2’
#
# 4_lig_opt_UNPD_indo 100%[===================>]   4.03K  --.-KB/s    in 0s
#
# 2024-08-05 09:10:53 (55.9 MB/s) - ‘4_lig_opt_UNPD_indolinone_27.mol2’ saved [4130/4130]
#
# --2024-08-05 09:10:53--  https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/MD_preparation/ligands_top/5_lig_opt_UNPD_indolinone_41.mol2
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4659 (4.5K) [text/plain]
# Saving to: ‘5_lig_opt_UNPD_indolinone_41.mol2’
#
# 5_lig_opt_UNPD_indo 100%[===================>]   4.55K  --.-KB/s    in 0s
#
# 2024-08-05 09:10:54 (21.8 MB/s) - ‘5_lig_opt_UNPD_indolinone_41.mol2’ saved [4659/4659]
#
# --2024-08-05 09:10:54--  https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/MD_preparation/ligands_top/6_lig_opt_UNPD_indolinone_42.mol2
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3144 (3.1K) [text/plain]
# Saving to: ‘6_lig_opt_UNPD_indolinone_42.mol2’
#
# 6_lig_opt_UNPD_indo 100%[===================>]   3.07K  --.-KB/s    in 0s
#
# 2024-08-05 09:10:54 (44.3 MB/s) - ‘6_lig_opt_UNPD_indolinone_42.mol2’ saved [3144/3144]
#
# --2024-08-05 09:10:54--  https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/MD_preparation/ligands_control/1_lig_opt_control_1.mol2
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1803 (1.8K) [text/plain]
# Saving to: ‘1_lig_opt_control_1.mol2’
#
# 1_lig_opt_control_1 100%[===================>]   1.76K  --.-KB/s    in 0s
#
# 2024-08-05 09:10:54 (25.6 MB/s) - ‘1_lig_opt_control_1.mol2’ saved [1803/1803]
#
# --2024-08-05 09:10:54--  https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/MD_preparation/ligands_control/2_lig_opt_control_2.mol2
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3419 (3.3K) [text/plain]
# Saving to: ‘2_lig_opt_control_2.mol2’
#
# 2_lig_opt_control_2 100%[===================>]   3.34K  --.-KB/s    in 0s
#
# 2024-08-05 09:10:54 (56.5 MB/s) - ‘2_lig_opt_control_2.mol2’ saved [3419/3419]
#
# --2024-08-05 09:10:55--  https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/MD_preparation/ligands_control/3_lig_opt_control_3.mol2
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3722 (3.6K) [text/plain]
# Saving to: ‘3_lig_opt_control_3.mol2’
#
# 3_lig_opt_control_3 100%[===================>]   3.63K  --.-KB/s    in 0s
#
# 2024-08-05 09:10:55 (44.7 MB/s) - ‘3_lig_opt_control_3.mol2’ saved [3722/3722]
#
# --2024-08-05 09:10:55--  https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/MD_preparation/ligands_control/4_lig_opt_control_4.mol2
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4025 (3.9K) [text/plain]
# Saving to: ‘4_lig_opt_control_4.mol2’
#
# 4_lig_opt_control_4 100%[===================>]   3.93K  --.-KB/s    in 0s
#
# 2024-08-05 09:10:55 (53.7 MB/s) - ‘4_lig_opt_control_4.mol2’ saved [4025/4025]

# %%
# Run sort_mol2_bonds.pl
# !perl sort_mol2_bonds.pl 1_lig_opt_DrugBank_stilbene_8.mol2 1_lig_opt_DrugBank_stilbene_8_fix.mol2
# !perl sort_mol2_bonds.pl 2_lig_opt_PubChem_flavanol_399.mol2 2_lig_opt_PubChem_flavanol_399_fix.mol2
# !perl sort_mol2_bonds.pl 3_lig_opt_PubChem_flavanol_451.mol2 3_lig_opt_PubChem_flavanol_451_fix.mol2
# !perl sort_mol2_bonds.pl 4_lig_opt_UNPD_indolinone_27.mol2 4_lig_opt_UNPD_indolinone_27_fix.mol2
# !perl sort_mol2_bonds.pl 5_lig_opt_UNPD_indolinone_41.mol2 5_lig_opt_UNPD_indolinone_41_fix.mol2
# !perl sort_mol2_bonds.pl 6_lig_opt_UNPD_indolinone_42.mol2 6_lig_opt_UNPD_indolinone_42_fix.mol2
# !perl sort_mol2_bonds.pl 1_lig_opt_control_1.mol2 1_lig_opt_control_1_fix.mol2
# !perl sort_mol2_bonds.pl 2_lig_opt_control_2.mol2 2_lig_opt_control_2_fix.mol2
# !perl sort_mol2_bonds.pl 3_lig_opt_control_3.mol2 3_lig_opt_control_3_fix.mol2
# !perl sort_mol2_bonds.pl 4_lig_opt_control_4.mol2 4_lig_opt_control_4_fix.mol2
# Out:
# Found 48 atoms in the molecule, with 52 bonds.
# Found 34 atoms in the molecule, with 37 bonds.
# Found 43 atoms in the molecule, with 45 bonds.
# Found 39 atoms in the molecule, with 43 bonds.
# Found 44 atoms in the molecule, with 49 bonds.
# Found 29 atoms in the molecule, with 34 bonds.
# Found 17 atoms in the molecule, with 17 bonds.
# Found 33 atoms in the molecule, with 33 bonds.
# Found 36 atoms in the molecule, with 36 bonds.
# Found 39 atoms in the molecule, with 39 bonds.

# %%
# Download STR files (generated in CGenFF)
# !wget https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/MD_preparation/ligands_top_GGenFF/1_lig_opt_DrugBank_stilbene_8_fix/1_lig_opt_DrugBank_stilbene_8_fix.str
# !wget https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/MD_preparation/ligands_top_GGenFF/2_lig_opt_PubChem_flavanol_399_fix/2_lig_opt_PubChem_flavanol_399_fix.str
# !wget https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/MD_preparation/ligands_top_GGenFF/3_lig_opt_PubChem_flavanol_451_fix/3_lig_opt_PubChem_flavanol_451_fix.str
# !wget https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/MD_preparation/ligands_top_GGenFF/4_lig_opt_UNPD_indolinone_27_fix/4_lig_opt_UNPD_indolinone_27_fix.str
# !wget https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/MD_preparation/ligands_top_GGenFF/5_lig_opt_UNPD_indolinone_41_fix/5_lig_opt_UNPD_indolinone_41_fix.str
# !wget https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/MD_preparation/ligands_top_GGenFF/6_lig_opt_UNPD_indolinone_42_fix/6_lig_opt_UNPD_indolinone_42_fix.str
# !wget https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/MD_preparation/ligands_control_GGenFF/1_lig_opt_control_1_fix/1_lig_opt_control_1_fix.str
# !wget https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/MD_preparation/ligands_control_GGenFF/2_lig_opt_control_2_fix/2_lig_opt_control_2_fix.str
# !wget https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/MD_preparation/ligands_control_GGenFF/3_lig_opt_control_3_fix/3_lig_opt_control_3_fix.str
# !wget https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/MD_preparation/ligands_control_GGenFF/4_lig_opt_control_4_fix/4_lig_opt_control_4_fix.str
# Out:
# --2024-08-05 09:45:45--  https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/MD_preparation/ligands_top_GGenFF/1_lig_opt_DrugBank_stilbene_8_fix/1_lig_opt_DrugBank_stilbene_8_fix.str
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 15075 (15K) [text/plain]
# Saving to: ‘1_lig_opt_DrugBank_stilbene_8_fix.str’
#
# 1_lig_opt_DrugBank_ 100%[===================>]  14.72K  --.-KB/s    in 0.001s
#
# 2024-08-05 09:45:46 (24.3 MB/s) - ‘1_lig_opt_DrugBank_stilbene_8_fix.str’ saved [15075/15075]
#
# --2024-08-05 09:45:46--  https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/MD_preparation/ligands_top_GGenFF/2_lig_opt_PubChem_flavanol_399_fix/2_lig_opt_PubChem_flavanol_399_fix.str
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12030 (12K) [text/plain]
# Saving to: ‘2_lig_opt_PubChem_flavanol_399_fix.str’
#
# 2_lig_opt_PubChem_f 100%[===================>]  11.75K  --.-KB/s    in 0s
#
# 2024-08-05 09:45:46 (93.5 MB/s) - ‘2_lig_opt_PubChem_flavanol_399_fix.str’ saved [12030/12030]
#
# --2024-08-05 09:45:46--  https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/MD_preparation/ligands_top_GGenFF/3_lig_opt_PubChem_flavanol_451_fix/3_lig_opt_PubChem_flavanol_451_fix.str
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7258 (7.1K) [text/plain]
# Saving to: ‘3_lig_opt_PubChem_flavanol_451_fix.str’
#
# 3_lig_opt_PubChem_f 100%[===================>]   7.09K  --.-KB/s    in 0s
#
# 2024-08-05 09:45:46 (47.2 MB/s) - ‘3_lig_opt_PubChem_flavanol_451_fix.str’ saved [7258/7258]
#
# --2024-08-05 09:45:46--  https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/MD_preparation/ligands_top_GGenFF/4_lig_opt_UNPD_indolinone_27_fix/4_lig_opt_UNPD_indolinone_27_fix.str
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10089 (9.9K) [text/plain]
# Saving to: ‘4_lig_opt_UNPD_indolinone_27_fix.str’
#
# 4_lig_opt_UNPD_indo 100%[===================>]   9.85K  --.-KB/s    in 0s
#
# 2024-08-05 09:45:46 (73.9 MB/s) - ‘4_lig_opt_UNPD_indolinone_27_fix.str’ saved [10089/10089]
#
# --2024-08-05 09:45:46--  https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/MD_preparation/ligands_top_GGenFF/5_lig_opt_UNPD_indolinone_41_fix/5_lig_opt_UNPD_indolinone_41_fix.str
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 16475 (16K) [text/plain]
# Saving to: ‘5_lig_opt_UNPD_indolinone_41_fix.str’
#
# 5_lig_opt_UNPD_indo 100%[===================>]  16.09K  --.-KB/s    in 0.001s
#
# 2024-08-05 09:45:47 (22.7 MB/s) - ‘5_lig_opt_UNPD_indolinone_41_fix.str’ saved [16475/16475]
#
# --2024-08-05 09:45:47--  https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/MD_preparation/ligands_top_GGenFF/6_lig_opt_UNPD_indolinone_42_fix/6_lig_opt_UNPD_indolinone_42_fix.str
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 944 [text/plain]
# Saving to: ‘6_lig_opt_UNPD_indolinone_42_fix.str’
#
# 6_lig_opt_UNPD_indo 100%[===================>]     944  --.-KB/s    in 0s
#
# 2024-08-05 09:45:47 (44.9 MB/s) - ‘6_lig_opt_UNPD_indolinone_42_fix.str’ saved [944/944]
#
# --2024-08-05 09:45:47--  https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/MD_preparation/ligands_control_GGenFF/1_lig_opt_control_1_fix/1_lig_opt_control_1_fix.str
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2570 (2.5K) [text/plain]
# Saving to: ‘1_lig_opt_control_1_fix.str’
#
# 1_lig_opt_control_1 100%[===================>]   2.51K  --.-KB/s    in 0s
#
# 2024-08-05 09:45:47 (30.0 MB/s) - ‘1_lig_opt_control_1_fix.str’ saved [2570/2570]
#
# --2024-08-05 09:45:47--  https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/MD_preparation/ligands_control_GGenFF/2_lig_opt_control_2_fix/2_lig_opt_control_2_fix.str
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4488 (4.4K) [text/plain]
# Saving to: ‘2_lig_opt_control_2_fix.str’
#
# 2_lig_opt_control_2 100%[===================>]   4.38K  --.-KB/s    in 0s
#
# 2024-08-05 09:45:47 (52.8 MB/s) - ‘2_lig_opt_control_2_fix.str’ saved [4488/4488]
#
# --2024-08-05 09:45:47--  https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/MD_preparation/ligands_control_GGenFF/3_lig_opt_control_3_fix/3_lig_opt_control_3_fix.str
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5793 (5.7K) [text/plain]
# Saving to: ‘3_lig_opt_control_3_fix.str’
#
# 3_lig_opt_control_3 100%[===================>]   5.66K  --.-KB/s    in 0s
#
# 2024-08-05 09:45:47 (48.4 MB/s) - ‘3_lig_opt_control_3_fix.str’ saved [5793/5793]
#
# --2024-08-05 09:45:47--  https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/MD_preparation/ligands_control_GGenFF/4_lig_opt_control_4_fix/4_lig_opt_control_4_fix.str
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5706 (5.6K) [text/plain]
# Saving to: ‘4_lig_opt_control_4_fix.str’
#
# 4_lig_opt_control_4 100%[===================>]   5.57K  --.-KB/s    in 0s
#
# 2024-08-05 09:45:48 (61.7 MB/s) - ‘4_lig_opt_control_4_fix.str’ saved [5706/5706]

# %%
# Download the script cgenff_charmm2gmx_py3_nx2.py
# !wget https://raw.githubusercontent.com/Lemkul-Lab/cgenff_charmm2gmx/main/cgenff_charmm2gmx_py3_nx2.py
# Out:
# --2024-08-05 09:45:42--  https://raw.githubusercontent.com/Lemkul-Lab/cgenff_charmm2gmx/main/cgenff_charmm2gmx_py3_nx2.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 37837 (37K) [text/plain]
# Saving to: ‘cgenff_charmm2gmx_py3_nx2.py’
#
# cgenff_charmm2gmx_p 100%[===================>]  36.95K  --.-KB/s    in 0.01s
#
# 2024-08-05 09:45:42 (3.28 MB/s) - ‘cgenff_charmm2gmx_py3_nx2.py’ saved [37837/37837]

# %%
# Prepare colab enviroment
# !apt-get install python3.7
# !sudo update-alternatives --install /usr/bin/python3 python3 /usr/bin/python3.7 1
# !sudo apt install python3-pip
# !apt-get install python3-distutils
# !sudo apt-get install --reinstall python3.7-distutils
# !pip uninstall networkx
# !pip install networkx==2.3
# !pip install numpy
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libpython3.7-minimal libpython3.7-stdlib mailcap mime-support python3.7-minimal
# Suggested packages:
#   python3.7-venv binfmt-support
# The following NEW packages will be installed:
#   libpython3.7-minimal libpython3.7-stdlib mailcap mime-support python3.7 python3.7-minimal
# 0 upgraded, 6 newly installed, 0 to remove and 45 not upgraded.
# Need to get 4,698 kB of archives.
# After this operation, 17.8 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 mailcap all 3.70+nmu1ubuntu1 [23.8 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 mime-support all 3.66 [3,696 B]
# Get:3 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 libpython3.7-minimal amd64 3.7.17-1+jammy1 [608 kB]
# Get:4 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 python3.7-minimal amd64 3.7.17-1+jammy1 [1,837 kB]
# Get:5 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 libpython3.7-stdlib amd64 3.7.17-1+jammy1 [1,864 kB]
# Get:6 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 python3.7 amd64 3.7.17-1+jammy1 [362 kB]
# Fetched 4,698 kB in 4s (1,086 kB/s)
# Selecting previously unselected package libpython3.7-minimal:amd64.
# (Reading database ... 149091 files and directories currently installed.)
# Preparing to unpack .../0-libpython3.7-minimal_3.7.17-1+jammy1_amd64.deb ...
# Unpacking libpython3.7-minimal:amd64 (3.7.17-1+jammy1) ...
# Selecting previously unselected package python3.7-minimal.
# Preparing to unpack .../1-python3.7-minimal_3.7.17-1+jammy1_amd64.deb ...
# Unpacking python3.7-minimal (3.7.17-1+jammy1) ...
# Selecting previously unselected package mailcap.
# Preparing to unpack .../2-mailcap_3.70+nmu1ubuntu1_all.deb ...
# Unpacking mailcap (3.70+nmu1ubuntu1) ...
# Selecting previously unselected package mime-support.
# Preparing to unpack .../3-mime-support_3.66_all.deb ...
# Unpacking mime-support (3.66) ...
# Selecting previously unselected package libpython3.7-stdlib:amd64.
# Preparing to unpack .../4-libpython3.7-stdlib_3.7.17-1+jammy1_amd64.deb ...
# Unpacking libpython3.7-stdlib:amd64 (3.7.17-1+jammy1) ...
# Selecting previously unselected package python3.7.
# Preparing to unpack .../5-python3.7_3.7.17-1+jammy1_amd64.deb ...
# Unpacking python3.7 (3.7.17-1+jammy1) ...
# Setting up libpython3.7-minimal:amd64 (3.7.17-1+jammy1) ...
# Setting up python3.7-minimal (3.7.17-1+jammy1) ...
# Setting up mailcap (3.70+nmu1ubuntu1) ...
# Setting up mime-support (3.66) ...
# Setting up libpython3.7-stdlib:amd64 (3.7.17-1+jammy1) ...
# Setting up python3.7 (3.7.17-1+jammy1) ...
# Processing triggers for man-db (2.10.2-1) ...

# %%
# Run cgenff_charmm2gmx_py3_nx2.py
# !python cgenff_charmm2gmx_py3_nx2.py TOP1 1_lig_opt_DrugBank_stilbene_8_fix.mol2 1_lig_opt_DrugBank_stilbene_8_fix.str charmm36-jul2022.ff
# !python cgenff_charmm2gmx_py3_nx2.py TOP2 2_lig_opt_PubChem_flavanol_399_fix.mol2 2_lig_opt_PubChem_flavanol_399_fix.str charmm36-jul2022.ff
# !python cgenff_charmm2gmx_py3_nx2.py TOP3 3_lig_opt_PubChem_flavanol_451_fix.mol2 3_lig_opt_PubChem_flavanol_451_fix.str charmm36-jul2022.ff
# !python cgenff_charmm2gmx_py3_nx2.py TOP4 4_lig_opt_UNPD_indolinone_27_fix.mol2 4_lig_opt_UNPD_indolinone_27_fix.str charmm36-jul2022.ff
# !python cgenff_charmm2gmx_py3_nx2.py TOP5 5_lig_opt_UNPD_indolinone_41_fix.mol2 5_lig_opt_UNPD_indolinone_41_fix.str charmm36-jul2022.ff
# !python cgenff_charmm2gmx_py3_nx2.py TOP6 6_lig_opt_UNPD_indolinone_42_fix.mol2 6_lig_opt_UNPD_indolinone_42_fix.str charmm36-jul2022.ff
# !python cgenff_charmm2gmx_py3_nx2.py CTL1 1_lig_opt_control_1_fix.mol2 1_lig_opt_control_1_fix.str charmm36-jul2022.ff
# !python cgenff_charmm2gmx_py3_nx2.py CTL2 2_lig_opt_control_2_fix.mol2 2_lig_opt_control_2_fix.str charmm36-jul2022.ff
# !python cgenff_charmm2gmx_py3_nx2.py CTL3 3_lig_opt_control_3_fix.mol2 3_lig_opt_control_3_fix.str charmm36-jul2022.ff
# !python cgenff_charmm2gmx_py3_nx2.py CTL4 4_lig_opt_control_4_fix.mol2 4_lig_opt_control_4_fix.str charmm36-jul2022.ff
# Out:
# NOTE 1: Code tested with Python 3.5.2 and 3.7.3. Your version: 3.7.17 (default, Jun  6 2023, 20:10:09)
# [GCC 11.3.0]
#
# NOTE 2: Code tested with NetworkX 2.3. Your version: 2.3
#
# NOTE 3: Please be sure to use the same version of CGenFF in your simulations that was used during parameter generation:
# --Version of CGenFF detected in  1_lig_opt_DrugBank_stilbene_8_fix.str : 4.6
# --Version of CGenFF detected in  charmm36-jul2022.ff/forcefield.doc : 4.6
#
# NOTE 4: To avoid duplicated parameters, do NOT select the 'Include parameters that are already in CGenFF' option when uploading a molecule into CGenFF.
# ============ DONE ============
# Conversion complete.
# The molecule topology has been written to top1.itp
# Additional parameters needed by the molecule are written to top1.prm, which needs to be included in the system .top
#
# PLEASE NOTE: If your topology has lone pairs, you must use GROMACS version 2020 or newer to use 2fd construction
# Older GROMACS versions WILL NOT WORK as they do not support 2fd virtual site construction
#
# ============ DONE ============
# NOTE 1: Code tested with Python 3.5.2 and 3.7.3. Your version: 3.7.17 (default, Jun  6 2023, 20:10:09)
# [GCC 11.3.0]
#
# NOTE 2: Code tested with NetworkX 2.3. Your version: 2.3
#
# NOTE 3: Please be sure to use the same version of CGenFF in your simulations that was used during parameter generation:
# --Version of CGenFF detected in  2_lig_opt_PubChem_flavanol_399_fix.str : 4.6
# --Version of CGenFF detected in  charmm36-jul2022.ff/forcefield.doc : 4.6
#
# NOTE 4: To avoid duplicated parameters, do NOT select the 'Include parameters that are already in CGenFF' option when uploading a molecule into CGenFF.
# ============ DONE ============
# Conversion complete.
# The molecule topology has been written to top2.itp
# Additional parameters needed by the molecule are written to top2.prm, which needs to be included in the system .top
#
# PLEASE NOTE: If your topology has lone pairs, you must use GROMACS version 2020 or newer to use 2fd construction
# Older GROMACS versions WILL NOT WORK as they do not support 2fd virtual site construction
#
# ============ DONE ============
# NOTE 1: Code tested with Python 3.5.2 and 3.7.3. Your version: 3.7.17 (default, Jun  6 2023, 20:10:09)
# [GCC 11.3.0]
#
# NOTE 2: Code tested with NetworkX 2.3. Your version: 2.3
#
# NOTE 3: Please be sure to use the same version of CGenFF in your simulations that was used during parameter generation:
# --Version of CGenFF detected in  3_lig_opt_PubChem_flavanol_451_fix.str : 4.6
# --Version of CGenFF detected in  charmm36-jul2022.ff/forcefield.doc : 4.6
#
# NOTE 4: To avoid duplicated parameters, do NOT select the 'Include parameters that are already in CGenFF' option when uploading a molecule into CGenFF.
# ============ DONE ============
# Conversion complete.
# The molecule topology has been written to top3.itp
# Additional parameters needed by the molecule are written to top3.prm, which needs to be included in the system .top
#
# PLEASE NOTE: If your topology has lone pairs, you must use GROMACS version 2020 or newer to use 2fd construction
# Older GROMACS versions WILL NOT WORK as they do not support 2fd virtual site construction
#
# ============ DONE ============
# NOTE 1: Code tested with Python 3.5.2 and 3.7.3. Your version: 3.7.17 (default, Jun  6 2023, 20:10:09)
# [GCC 11.3.0]
#
# NOTE 2: Code tested with NetworkX 2.3. Your version: 2.3
#
# NOTE 3: Please be sure to use the same version of CGenFF in your simulations that was used during parameter generation:
# --Version of CGenFF detected in  4_lig_opt_UNPD_indolinone_27_fix.str : 4.6
# --Version of CGenFF detected in  charmm36-jul2022.ff/forcefield.doc : 4.6
#
# NOTE 4: To avoid duplicated parameters, do NOT select the 'Include parameters that are already in CGenFF' option when uploading a molecule into CGenFF.
# ============ DONE ============
# Conversion complete.
# The molecule topology has been written to top4.itp
# Additional parameters needed by the molecule are written to top4.prm, which needs to be included in the system .top
#
# PLEASE NOTE: If your topology has lone pairs, you must use GROMACS version 2020 or newer to use 2fd construction
# Older GROMACS versions WILL NOT WORK as they do not support 2fd virtual site construction
#
# ============ DONE ============
# NOTE 1: Code tested with Python 3.5.2 and 3.7.3. Your version: 3.7.17 (default, Jun  6 2023, 20:10:09)
# [GCC 11.3.0]
#
# NOTE 2: Code tested with NetworkX 2.3. Your version: 2.3
#
# NOTE 3: Please be sure to use the same version of CGenFF in your simulations that was used during parameter generation:
# --Version of CGenFF detected in  5_lig_opt_UNPD_indolinone_41_fix.str : 4.6
# --Version of CGenFF detected in  charmm36-jul2022.ff/forcefield.doc : 4.6
#
# NOTE 4: To avoid duplicated parameters, do NOT select the 'Include parameters that are already in CGenFF' option when uploading a molecule into CGenFF.
# ============ DONE ============
# Conversion complete.
# The molecule topology has been written to top5.itp
# Additional parameters needed by the molecule are written to top5.prm, which needs to be included in the system .top
#
# PLEASE NOTE: If your topology has lone pairs, you must use GROMACS version 2020 or newer to use 2fd construction
# Older GROMACS versions WILL NOT WORK as they do not support 2fd virtual site construction
#
# ============ DONE ============
# NOTE 1: Code tested with Python 3.5.2 and 3.7.3. Your version: 3.7.17 (default, Jun  6 2023, 20:10:09)
# [GCC 11.3.0]
#
# NOTE 2: Code tested with NetworkX 2.3. Your version: 2.3
#
# NOTE 3: Please be sure to use the same version of CGenFF in your simulations that was used during parameter generation:
# --Version of CGenFF detected in  6_lig_opt_UNPD_indolinone_42_fix.str : 4.6
# --Version of CGenFF detected in  charmm36-jul2022.ff/forcefield.doc : 4.6
#
# NOTE 4: To avoid duplicated parameters, do NOT select the 'Include parameters that are already in CGenFF' option when uploading a molecule into CGenFF.
# Error in atomgroup.py: read_mol2_coor_only: no. of atoms in mol2 (29) and top (0) are unequal
# Usually this means the specified residue name does not match between str and mol2 files
# NOTE 1: Code tested with Python 3.5.2 and 3.7.3. Your version: 3.7.17 (default, Jun  6 2023, 20:10:09)
# [GCC 11.3.0]
#
# NOTE 2: Code tested with NetworkX 2.3. Your version: 2.3
#
# NOTE 3: Please be sure to use the same version of CGenFF in your simulations that was used during parameter generation:
# --Version of CGenFF detected in  1_lig_opt_control_1_fix.str : 4.6
# --Version of CGenFF detected in  charmm36-jul2022.ff/forcefield.doc : 4.6
#
# NOTE 4: To avoid duplicated parameters, do NOT select the 'Include parameters that are already in CGenFF' option when uploading a molecule into CGenFF.
# ============ DONE ============
# Conversion complete.
# The molecule topology has been written to ctl1.itp
# Additional parameters needed by the molecule are written to ctl1.prm, which needs to be included in the system .top
#
# PLEASE NOTE: If your topology has lone pairs, you must use GROMACS version 2020 or newer to use 2fd construction
# Older GROMACS versions WILL NOT WORK as they do not support 2fd virtual site construction
#
# ============ DONE ============
# NOTE 1: Code tested with Python 3.5.2 and 3.7.3. Your version: 3.7.17 (default, Jun  6 2023, 20:10:09)
# [GCC 11.3.0]
#
# NOTE 2: Code tested with NetworkX 2.3. Your version: 2.3
#
# NOTE 3: Please be sure to use the same version of CGenFF in your simulations that was used during parameter generation:
# --Version of CGenFF detected in  2_lig_opt_control_2_fix.str : 4.6
# --Version of CGenFF detected in  charmm36-jul2022.ff/forcefield.doc : 4.6
#
# NOTE 4: To avoid duplicated parameters, do NOT select the 'Include parameters that are already in CGenFF' option when uploading a molecule into CGenFF.
# ============ DONE ============
# Conversion complete.
# The molecule topology has been written to ctl2.itp
# Additional parameters needed by the molecule are written to ctl2.prm, which needs to be included in the system .top
#
# PLEASE NOTE: If your topology has lone pairs, you must use GROMACS version 2020 or newer to use 2fd construction
# Older GROMACS versions WILL NOT WORK as they do not support 2fd virtual site construction
#
# ============ DONE ============
# NOTE 1: Code tested with Python 3.5.2 and 3.7.3. Your version: 3.7.17 (default, Jun  6 2023, 20:10:09)
# [GCC 11.3.0]
#
# NOTE 2: Code tested with NetworkX 2.3. Your version: 2.3
#
# NOTE 3: Please be sure to use the same version of CGenFF in your simulations that was used during parameter generation:
# --Version of CGenFF detected in  3_lig_opt_control_3_fix.str : 4.6
# --Version of CGenFF detected in  charmm36-jul2022.ff/forcefield.doc : 4.6
#
# NOTE 4: To avoid duplicated parameters, do NOT select the 'Include parameters that are already in CGenFF' option when uploading a molecule into CGenFF.
#
# NOTE 5: 2 lone pairs found in topology that are not in the mol2 file. This is not a problem, just FYI!
#
# ============ DONE ============
# Conversion complete.
# The molecule topology has been written to ctl3.itp
# Additional parameters needed by the molecule are written to ctl3.prm, which needs to be included in the system .top
#
# PLEASE NOTE: If your topology has lone pairs, you must use GROMACS version 2020 or newer to use 2fd construction
# Older GROMACS versions WILL NOT WORK as they do not support 2fd virtual site construction
#
# ============ DONE ============
# NOTE 1: Code tested with Python 3.5.2 and 3.7.3. Your version: 3.7.17 (default, Jun  6 2023, 20:10:09)
# [GCC 11.3.0]
#
# NOTE 2: Code tested with NetworkX 2.3. Your version: 2.3
#
# NOTE 3: Please be sure to use the same version of CGenFF in your simulations that was used during parameter generation:
# --Version of CGenFF detected in  4_lig_opt_control_4_fix.str : 4.6
# --Version of CGenFF detected in  charmm36-jul2022.ff/forcefield.doc : 4.6
#
# NOTE 4: To avoid duplicated parameters, do NOT select the 'Include parameters that are already in CGenFF' option when uploading a molecule into CGenFF.
# ============ DONE ============
# Conversion complete.
# The molecule topology has been written to ctl4.itp
# Additional parameters needed by the molecule are written to ctl4.prm, which needs to be included in the system .top
#
# PLEASE NOTE: If your topology has lone pairs, you must use GROMACS version 2020 or newer to use 2fd construction
# Older GROMACS versions WILL NOT WORK as they do not support 2fd virtual site construction
#
# ============ DONE ============
