# %%
import pandas as pd

# %%
PeruNPDB = pd.read_csv('PeruNPDB.csv', names=['SMILES'])

# %%
pd.head()
# Out:
#                                               SMILES
# 0           CC=C1C2C3(C=CC4C3C(O2)OC=C4C(=O)OC)OC1=O
# 1           CC=C1C2C3(C=CC4C3C(O2)OC=C4C(=O)OC)OC1=O
# 2  CC(=O)OCC1=C\2C(CC(C)(O)C3(O)CCC(O3)\C=C2OC1=O...
# 3  CCOCC1=C\2C(CC(C)(O)C3(O)CCC(O3)\C=C2OC1=O)OC(...
# 4  CC1CCC2(CCC3(C(=CCC4C3(CCC5C4(CCC(C5(C)C)O)C)C...

# %%
pd.dtypes
# Out:
# SMILES    object
# dtype: object

# %%
UNPD = pd.read_csv('UNPD_DB.csv')

# %%
UNPD
# Out:
#            PMA_ID                                              InChI  \
# 0      PMA_000001  InChI=1/C20H26O4/c1-12(2)17-11-18(22)14(4)7-5-...
# 1      PMA_000002  InChI=1/C62H92Cl2O33/c1-22-14-35(82-23(2)41(22...
# 2      PMA_000003  InChI=1/C20H19NO4/c1-20(2)9-8-11-15(25-20)10-1...
# 3      PMA_000004  InChI=1/C35H64O8/c1-3-4-5-6-7-8-9-10-11-15-18-...
# 4      PMA_000005  InChI=1/C17H24O5/c1-9(18)22-13-12(19)11-10(8-2...
# ...           ...                                                ...
# 14284  PMA_014699  InChI=1/C30H44O7/c1-15(10-17(31)11-16(2)26(36)...
# 14285  PMA_014700  InChI=1/C21H22O9/c1-8-5-10-15(12(24)6-8)17(26)...
# 14286  PMA_014701  InChI=1/C17H24O5/c1-9-5-6-13(19)10(2)8-15-16(1...
# 14287  PMA_014702  InChI=1/C18H15N3OS/c19-7-5-12-15-14-11(10-3-1-...
# 14288  PMA_014703  InChI=1/C59H96O27/c1-54(2)14-16-59(53(76)86-51...
#
#          EXACTMASS   PARENTMASS CHARGE   SEQ   IONMODE     id     UNPD_ID  \
# ...
