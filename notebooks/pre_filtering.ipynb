# %%
! pip install rdkit-pypi
! pip install pubchempy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.4/29.4 MB 45.4 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pubchempy: filename=PubChemPy-1.0.4-py3-none-any.whl size=13820 sha256=ccb1b53848cb958bf8657389c64983b0717180c2cdc79244940e8727b694ef9f
#   Stored in directory: /root/.cache/pip/wheels/90/7c/45/18a0671e3c3316966ef7ed9ad2b3f3300a7e41d3421a44e799
# Successfully built pubchempy
# ...

# %%
# Import libraries
import pandas as pd
import numpy as np
import pubchempy as pcp
from rdkit import Chem
from rdkit.Chem import PandasTools
from rdkit.Chem.Draw import MolsToGridImage

# %%
# Querys
sulfonamide = Chem.MolFromSmiles('OC1=C2C=CC=CC2=C(S(=O)(N)=O)C=C1')
indolinone = Chem.MolFromSmiles('O=C1NC2=C(C=CC=C2)C1')
curcumin = Chem.MolFromSmiles('O=C(/C=C/C1=CC=C(O)C(OC)=C1)CC(/C=C/C2=CC(OC)=C(O)C=C2)=O')
flavanol = Chem.MolFromSmiles('OC1(C2=CC=CC=C2)CCC3=C(O1)C=CC=C3')
stilbene = Chem.MolFromSmiles('C1(C=CC2=CC=CC=C2)=CC=CC=C1')

# %%
# Functions
def NewDataFrameFromSMILES(DataFrame,mol_list,query):
  df_temp = DataFrame.copy()
  for i in range(len(mol_list)):
    try:
      mol_list[i].GetSubstructMatch(query)
    except:
      df_temp.drop(i, inplace=True)

  mol_list_temp = [Chem.MolFromSmiles(x) for x in df_temp['SMILES']]
  match_list = [mol.GetSubstructMatch(query) for mol in mol_list_temp]
  return match_list

def NewDataFrameFromMolecule(DataFrame,mol_list,query):
  df_temp = DataFrame.copy()
  for i in range(len(mol_list)):
    try:
      mol_list[i].GetSubstructMatch(query)
    except:
      df_temp.drop(i, inplace=True)

  mol_list_temp = df_temp['Molecule'].tolist()
  match_list = [mol.GetSubstructMatch(query) for mol in mol_list_temp]
  return match_list

# %% [markdown]
# # **PubChem**

# %% [markdown]
# ## *(4-hydroxynaphthalen-1-yl)sulfonamide*

# %% [markdown]
# ## *indolinone*

# %%
url = 'https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/raw/PubChem_indolinone.csv'
df_PubChem_indolinone = pd.read_csv(url)
df_PubChem_indolinone['isosmiles'].isnull().sum()
# Out:
# 0

# %%
df_PubChem_indolinone = df_PubChem_indolinone['isosmiles']
df_PubChem_indolinone.to_csv('PubChem_indolinone.csv', index=False)

# %% [markdown]
# ## *curcumin*

# %%
url = 'https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/raw/PubChem_curcumin.csv'
df_PubChem_curcumin = pd.read_csv(url)
df_PubChem_curcumin['isosmiles'].isnull().sum()
# Out:
# 0

# %%
df_PubChem_curcumin = df_PubChem_curcumin['isosmiles']
df_PubChem_curcumin.to_csv('PubChem_curcumin.csv', index=False)

# %% [markdown]
# ## *Flavanol*

# %%
url = 'https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/raw/PubChem_flavanol.csv'
df_PubChem_flavanol = pd.read_csv(url)
df_PubChem_flavanol['isosmiles'].isnull().sum()
# Out:
# 0

# %%
df_PubChem_flavanol = df_PubChem_flavanol['isosmiles']
df_PubChem_flavanol.to_csv('PubChem_flavanol.csv', index=False)

# %% [markdown]
# ## *Stilben*

# %%
url = 'https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/raw/PubChem_stilbene.csv'
df_PubChem_stilbene = pd.read_csv(url)
df_PubChem_stilbene['isosmiles'].isnull().sum()
# Out:
# 0

# %%
df_PubChem_stilbene = df_PubChem_stilbene['isosmiles']
df_PubChem_stilbene.to_csv('PubChem_stilbene.csv', index=False)

# %% [markdown]
# # **PeruNPDB**

# %%
url = 'https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/raw/PeruNPDB.csv'
df_PeruNPDB = pd.read_csv(url, names=['SMILES'])
mol_list = [Chem.MolFromSmiles(x) for x in df_PeruNPDB['SMILES']]
# Out:
# [11:27:43] Explicit valence for atom # 2 C, 5, is greater than permitted

# %%
mol_list
# Out:
# ...
#  None,
# ...

# %% [markdown]
# ## *(4-hydroxynaphthalen-1-yl)sulfonamide*

# %%
match_list = NewDataFrameFromSMILES(df_PeruNPDB,mol_list,sulfonamide)

# %% [markdown]
# ## *Indolinone*

# %%
match_list = NewDataFrameFromSMILES(df_PeruNPDB,mol_list,indolinone)

# %% [markdown]
# ## *Curcumin*

# %%
match_list = NewDataFrameFromSMILES(df_PeruNPDB,mol_list,curcumin)

# %% [markdown]
# ## *Flavanol*

# %%
match_list = NewDataFrameFromSMILES(df_PeruNPDB,mol_list,flavanol)

# %% [markdown]
# ## *Stilbene*

# %%
match_list = NewDataFrameFromSMILES(df_PeruNPDB,mol_list,stilbene)

# %% [markdown]
# # **UNPD**

# %%
url = 'https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/raw/UNPD.csv'
df_UNPD = pd.read_csv(url)
mol_list = [Chem.MolFromSmiles(x) for x in df_UNPD['SMILES']]

# %% [markdown]
# ## *(4-hydroxynaphthalen-1-yl)sulfonamide*

# %%
match_list = NewDataFrameFromSMILES(df_UNPD,mol_list,sulfonamide)

# %% [markdown]
# ## *Indolinone*

# %%
match_list = NewDataFrameFromSMILES(df_UNPD,mol_list,indolinone)

# %% [markdown]
# ## *Curcumin*

# %%
match_list = NewDataFrameFromSMILES(df_UNPD,mol_list,curcumin)

# %% [markdown]
# ## *Flavanol*

# %%
match_list = NewDataFrameFromSMILES(df_UNPD,mol_list,flavanol)

# %% [markdown]
# ## *Stilbene*

# %%
match_list = NewDataFrameFromSMILES(df_UNPD,mol_list,stilbene)

# %% [markdown]
# # **NaturAr**

# %%
url = 'https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/raw/NaturAr.csv'
df_NaturAr = pd.read_csv(url)
mol_list = [Chem.MolFromSmiles(x) for x in df_NaturAr['SMILES']]

# %%
lico = Chem.MolFromSmiles('C[C@@H]1C[C@H]2Cc3ncccc3[C@]3(C1)NCCC[C@H]23')

# %%
match_list = NewDataFrameFromSMILES(df_NaturAr,mol_list,lico)

# %% [markdown]
# ## *(4-hydroxynaphthalen-1-yl)sulfonamide*

# %%
match_list = NewDataFrameFromSMILES(df_NaturAr,mol_list,sulfonamide)

# %% [markdown]
# ## *Indolinone*

# %%
match_list = NewDataFrameFromSMILES(df_NaturAr,mol_list,indolinone)

# %% [markdown]
# ## *Curcumin*

# %%
match_list = NewDataFrameFromSMILES(df_NaturAr,mol_list,curcumin)

# %% [markdown]
# ## *Flavanol*

# %%
match_list = NewDataFrameFromSMILES(df_NaturAr,mol_list,flavanol)

# %% [markdown]
# ## *Stilbene*

# %%
match_list = NewDataFrameFromSMILES(df_NaturAr,mol_list,stilbene)

# %% [markdown]
# # **NuBBE**

# %%
url = 'https://raw.githubusercontent.com/cpariona/biomedical-thesis/main/data/raw/NuBBE.csv'
df_NuBBE = pd.read_csv(url)
mol_list = df_NuBBE['Molecule'].tolist()

# %%
df_temp = df_NuBBE.copy()
for i in range(len(mol_list)):
  try:
    mol_list[i].GetSubstructMatch(curcumin)
  except:
    df_temp.drop(i, inplace=True)

mol_list_temp = df_temp['Molecule'].tolist()
match_list = [mol.GetSubstructMatch(curcumin) for mol in mol_list_temp]

# %%
match_list = NewDataFrameFromMolecule(df_NuBBE,mol_list,curcumin)

# %%
mol_list
# Out:
# ['<rdkit.Chem.rdchem.Mol object at 0x0000026C1610F990>',
#  '<rdkit.Chem.rdchem.Mol object at 0x0000026C161898C0>',
#  '<rdkit.Chem.rdchem.Mol object at 0x0000026C161893F0>',
#  '<rdkit.Chem.rdchem.Mol object at 0x0000026C16189150>',
#  '<rdkit.Chem.rdchem.Mol object at 0x0000026C16189540>',
#  nan,
#  nan,
#  nan,
#  '<rdkit.Chem.rdchem.Mol object at 0x0000026C16188C10>',
#  '<rdkit.Chem.rdchem.Mol object at 0x0000026C161897E0>',
#  '<rdkit.Chem.rdchem.Mol object at 0x0000026C16189690>',
#  nan,
#  nan,
#  '<rdkit.Chem.rdchem.Mol object at 0x0000026C16189000>',
#  '<rdkit.Chem.rdchem.Mol object at 0x0000026C16189770>',
#  '<rdkit.Chem.rdchem.Mol object at 0x0000026C16189930>',
#  '<rdkit.Chem.rdchem.Mol object at 0x0000026C16189A10>',
#  '<rdkit.Chem.rdchem.Mol object at 0x0000026C16189BD0>',
#  nan,
#  '<rdkit.Chem.rdchem.Mol object at 0x0000026C16189AF0>',
#  '<rdkit.Chem.rdchem.Mol object at 0x0000026C161899A0>',
#  '<rdkit.Chem.rdchem.Mol object at 0x0000026C16189B60>',
# ...

# %%
<rdkit.Chem.rdchem.Mol at 0x7b1a7286cc80>
# Out:
# Empty DataFrame
# Columns: [Molecule]
# Index: []
